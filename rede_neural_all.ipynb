# %%
import random
import os
import tensorflow as tf
from tensorflow.keras import layers, models
import cv2
import numpy as np
from tqdm import tqdm
import pandas as pd
import pickle

seed_number = 2024
random.seed(seed_number)
np.random.seed(seed_number)
tf.random.set_seed(seed_number)
# Out:
# 2025-01-28 19:11:00.121005: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-28 19:11:00.280573: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-28 19:11:00.358085: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-28 19:11:00.378825: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-28 19:11:00.505363: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.1 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/ajunior/.local/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/ajunior/.local/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/ajunior/.local/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "/home/ajunior/.local/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/ajunior/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "/home/ajunior/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "/home/ajunior/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#     await result
#   File "/home/ajunior/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 740, in execute_request
#     reply_content = await reply_content
#   File "/home/ajunior/.local/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/home/ajunior/.local/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 546, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/ajunior/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/home/ajunior/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/home/ajunior/.local/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/ajunior/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/ajunior/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/ajunior/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_79693/3505875762.py", line 3, in <module>
#     import tensorflow as tf
#   File "/home/ajunior/.local/lib/python3.10/site-packages/tensorflow/__init__.py", line 47, in <module>
#     from tensorflow._api.v2 import __internal__
#   File "/home/ajunior/.local/lib/python3.10/site-packages/tensorflow/_api/v2/__internal__/__init__.py", line 8, in <module>
#     from tensorflow._api.v2.__internal__ import autograph
#   File "/home/ajunior/.local/lib/python3.10/site-packages/tensorflow/_api/v2/__internal__/autograph/__init__.py", line 8, in <module>
#     from tensorflow.python.autograph.core.ag_ctx import control_status_ctx # line: 34
#   File "/home/ajunior/.local/lib/python3.10/site-packages/tensorflow/python/autograph/core/ag_ctx.py", line 21, in <module>
#     from tensorflow.python.autograph.utils import ag_logging
#   File "/home/ajunior/.local/lib/python3.10/site-packages/tensorflow/python/autograph/utils/__init__.py", line 17, in <module>
#     from tensorflow.python.autograph.utils.context_managers import control_dependency_on_returns
#   File "/home/ajunior/.local/lib/python3.10/site-packages/tensorflow/python/autograph/utils/context_managers.py", line 19, in <module>
#     from tensorflow.python.framework import ops
#   File "/home/ajunior/.local/lib/python3.10/site-packages/tensorflow/python/framework/ops.py", line 46, in <module>
#     from tensorflow.python import pywrap_tfe
#   File "/home/ajunior/.local/lib/python3.10/site-packages/tensorflow/python/pywrap_tfe.py", line 25, in <module>
#     from tensorflow.python._pywrap_tfe import *
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.1 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/ajunior/.local/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/ajunior/.local/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/ajunior/.local/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "/home/ajunior/.local/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/ajunior/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "/home/ajunior/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "/home/ajunior/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#     await result
#   File "/home/ajunior/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 740, in execute_request
#     reply_content = await reply_content
#   File "/home/ajunior/.local/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/home/ajunior/.local/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 546, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/ajunior/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/home/ajunior/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/home/ajunior/.local/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/ajunior/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/ajunior/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/ajunior/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_79693/3505875762.py", line 3, in <module>
#     import tensorflow as tf
#   File "/home/ajunior/.local/lib/python3.10/site-packages/tensorflow/__init__.py", line 47, in <module>
#     from tensorflow._api.v2 import __internal__
#   File "/home/ajunior/.local/lib/python3.10/site-packages/tensorflow/_api/v2/__internal__/__init__.py", line 8, in <module>
#     from tensorflow._api.v2.__internal__ import autograph
#   File "/home/ajunior/.local/lib/python3.10/site-packages/tensorflow/_api/v2/__internal__/autograph/__init__.py", line 8, in <module>
#     from tensorflow.python.autograph.core.ag_ctx import control_status_ctx # line: 34
#   File "/home/ajunior/.local/lib/python3.10/site-packages/tensorflow/python/autograph/core/ag_ctx.py", line 21, in <module>
#     from tensorflow.python.autograph.utils import ag_logging
#   File "/home/ajunior/.local/lib/python3.10/site-packages/tensorflow/python/autograph/utils/__init__.py", line 17, in <module>
#     from tensorflow.python.autograph.utils.context_managers import control_dependency_on_returns
#   File "/home/ajunior/.local/lib/python3.10/site-packages/tensorflow/python/autograph/utils/context_managers.py", line 19, in <module>
#     from tensorflow.python.framework import ops
#   File "/home/ajunior/.local/lib/python3.10/site-packages/tensorflow/python/framework/ops.py", line 49, in <module>
#     from tensorflow.python.client import pywrap_tf_session
#   File "/home/ajunior/.local/lib/python3.10/site-packages/tensorflow/python/client/pywrap_tf_session.py", line 19, in <module>
#     from tensorflow.python.client._pywrap_tf_session import *
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.1 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/ajunior/.local/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/ajunior/.local/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/ajunior/.local/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "/home/ajunior/.local/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/ajunior/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "/home/ajunior/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "/home/ajunior/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#     await result
#   File "/home/ajunior/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 740, in execute_request
#     reply_content = await reply_content
#   File "/home/ajunior/.local/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/home/ajunior/.local/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 546, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/ajunior/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/home/ajunior/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/home/ajunior/.local/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/ajunior/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/ajunior/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/ajunior/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_79693/3505875762.py", line 3, in <module>
#     import tensorflow as tf
#   File "/home/ajunior/.local/lib/python3.10/site-packages/tensorflow/__init__.py", line 47, in <module>
#     from tensorflow._api.v2 import __internal__
#   File "/home/ajunior/.local/lib/python3.10/site-packages/tensorflow/_api/v2/__internal__/__init__.py", line 11, in <module>
#     from tensorflow._api.v2.__internal__ import distribute
#   File "/home/ajunior/.local/lib/python3.10/site-packages/tensorflow/_api/v2/__internal__/distribute/__init__.py", line 8, in <module>
#     from tensorflow._api.v2.__internal__.distribute import combinations
#   File "/home/ajunior/.local/lib/python3.10/site-packages/tensorflow/_api/v2/__internal__/distribute/combinations/__init__.py", line 8, in <module>
#     from tensorflow.python.distribute.combinations import env # line: 456
#   File "/home/ajunior/.local/lib/python3.10/site-packages/tensorflow/python/distribute/combinations.py", line 33, in <module>
#     from tensorflow.python.distribute import collective_all_reduce_strategy
#   File "/home/ajunior/.local/lib/python3.10/site-packages/tensorflow/python/distribute/collective_all_reduce_strategy.py", line 25, in <module>
#     from tensorflow.python.distribute import cross_device_ops as cross_device_ops_lib
#   File "/home/ajunior/.local/lib/python3.10/site-packages/tensorflow/python/distribute/cross_device_ops.py", line 28, in <module>
#     from tensorflow.python.distribute import cross_device_utils
#   File "/home/ajunior/.local/lib/python3.10/site-packages/tensorflow/python/distribute/cross_device_utils.py", line 22, in <module>
#     from tensorflow.python.distribute import values as value_lib
#   File "/home/ajunior/.local/lib/python3.10/site-packages/tensorflow/python/distribute/values.py", line 23, in <module>
#     from tensorflow.python.distribute import distribute_lib
#   File "/home/ajunior/.local/lib/python3.10/site-packages/tensorflow/python/distribute/distribute_lib.py", line 205, in <module>
#     from tensorflow.python.data.ops import dataset_ops
#   File "/home/ajunior/.local/lib/python3.10/site-packages/tensorflow/python/data/__init__.py", line 21, in <module>
#     from tensorflow.python.data import experimental
#   File "/home/ajunior/.local/lib/python3.10/site-packages/tensorflow/python/data/experimental/__init__.py", line 98, in <module>
#     from tensorflow.python.data.experimental import service
#   File "/home/ajunior/.local/lib/python3.10/site-packages/tensorflow/python/data/experimental/service/__init__.py", line 419, in <module>
#     from tensorflow.python.data.experimental.ops.data_service_ops import distribute
#   File "/home/ajunior/.local/lib/python3.10/site-packages/tensorflow/python/data/experimental/ops/data_service_ops.py", line 26, in <module>
#     from tensorflow.python.data.ops import dataset_ops
#   File "/home/ajunior/.local/lib/python3.10/site-packages/tensorflow/python/data/ops/dataset_ops.py", line 34, in <module>
#     from tensorflow.python.data.ops import iterator_ops
#   File "/home/ajunior/.local/lib/python3.10/site-packages/tensorflow/python/data/ops/iterator_ops.py", line 45, in <module>
#     from tensorflow.python.training.saver import BaseSaverBuilder
#   File "/home/ajunior/.local/lib/python3.10/site-packages/tensorflow/python/training/saver.py", line 50, in <module>
#     from tensorflow.python.training import py_checkpoint_reader
#   File "/home/ajunior/.local/lib/python3.10/site-packages/tensorflow/python/training/py_checkpoint_reader.py", line 19, in <module>
#     from tensorflow.python.util._pywrap_checkpoint_reader import CheckpointReader
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 import random
#       2 import os
# ----> 3 import tensorflow as tf
#       4 from tensorflow.keras import layers, models
#       5 import cv2
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/__init__.py:47
#      44 from tensorflow.python import tf2 as _tf2
#      45 _tf2.enable()
# ---> 47 from tensorflow._api.v2 import __internal__
#      48 from tensorflow._api.v2 import __operators__
#      49 from tensorflow._api.v2 import audio
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/_api/v2/__internal__/__init__.py:11
#       9 from tensorflow._api.v2.__internal__ import decorator
#      10 from tensorflow._api.v2.__internal__ import dispatch
# ---> 11 from tensorflow._api.v2.__internal__ import distribute
#      12 from tensorflow._api.v2.__internal__ import eager_context
#      13 from tensorflow._api.v2.__internal__ import feature_column
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/_api/v2/__internal__/distribute/__init__.py:8
#       3 """Public API for tf._api.v2.__internal__.distribute namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.__internal__.distribute import combinations
#       9 from tensorflow._api.v2.__internal__.distribute import interim
#      10 from tensorflow._api.v2.__internal__.distribute import multi_process_runner
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/_api/v2/__internal__/distribute/combinations/__init__.py:8
#       3 """Public API for tf._api.v2.__internal__.distribute.combinations namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow.python.distribute.combinations import env # line: 456
#       9 from tensorflow.python.distribute.combinations import generate # line: 365
#      10 from tensorflow.python.distribute.combinations import in_main_process # line: 418
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/distribute/combinations.py:33
#      29 import six
#      32 from tensorflow.python.client import session
# ---> 33 from tensorflow.python.distribute import collective_all_reduce_strategy
#      34 from tensorflow.python.distribute import distribute_lib
#      35 from tensorflow.python.distribute import multi_process_runner
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/distribute/collective_all_reduce_strategy.py:25
#      23 from tensorflow.core.protobuf import tensorflow_server_pb2
#      24 from tensorflow.python.distribute import collective_util
# ---> 25 from tensorflow.python.distribute import cross_device_ops as cross_device_ops_lib
#      26 from tensorflow.python.distribute import cross_device_utils
#      27 from tensorflow.python.distribute import device_util
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/distribute/cross_device_ops.py:28
#      26 from tensorflow.python.client import device_lib
#      27 from tensorflow.python.distribute import collective_util
# ---> 28 from tensorflow.python.distribute import cross_device_utils
#      29 from tensorflow.python.distribute import device_util
#      30 from tensorflow.python.distribute import distribute_utils
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/distribute/cross_device_utils.py:22
#      19 from typing import Callable, List, Optional, Union
#      21 from tensorflow.python.distribute import collective_util
# ---> 22 from tensorflow.python.distribute import values as value_lib
#      23 from tensorflow.python.eager import backprop_util
#      24 from tensorflow.python.eager import context
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/distribute/values.py:23
#      21 from tensorflow.core.protobuf import struct_pb2
#      22 from tensorflow.python.distribute import device_util
# ---> 23 from tensorflow.python.distribute import distribute_lib
#      24 from tensorflow.python.distribute import packed_distributed_variable as packed
#      25 from tensorflow.python.distribute import reduce_util
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/distribute/distribute_lib.py:205
#     203 from tensorflow.python.autograph.core import ag_ctx as autograph_ctx
#     204 from tensorflow.python.autograph.impl import api as autograph
# --> 205 from tensorflow.python.data.ops import dataset_ops
#     206 from tensorflow.python.distribute import collective_util
#     207 from tensorflow.python.distribute import device_util
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/data/__init__.py:21
#      15 """`tf.data.Dataset` API for input pipelines.
#      16
#      17 See [Importing Data](https://tensorflow.org/guide/data) for an overview.
#      18 """
#      20 # pylint: disable=unused-import
# ---> 21 from tensorflow.python.data import experimental
#      22 from tensorflow.python.data.ops.dataset_ops import AUTOTUNE
#      23 from tensorflow.python.data.ops.dataset_ops import Dataset
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/data/experimental/__init__.py:98
#      15 """Experimental API for building input pipelines.
#      16
#      17 This module contains experimental `Dataset` sources and transformations that can
#    (...)
#      94 @@UNKNOWN_CARDINALITY
#      95 """
#      97 # pylint: disable=unused-import
# ---> 98 from tensorflow.python.data.experimental import service
#      99 from tensorflow.python.data.experimental.ops.batching import dense_to_ragged_batch
#     100 from tensorflow.python.data.experimental.ops.batching import dense_to_sparse_batch
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/data/experimental/service/__init__.py:419
#       1 # Copyright 2020 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """API for using the tf.data service.
#      16
#      17 This module contains:
#    (...)
#     416   job of ParameterServerStrategy).
#     417 """
# --> 419 from tensorflow.python.data.experimental.ops.data_service_ops import distribute
#     420 from tensorflow.python.data.experimental.ops.data_service_ops import from_dataset_id
#     421 from tensorflow.python.data.experimental.ops.data_service_ops import register_dataset
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/data/experimental/ops/data_service_ops.py:26
#      24 from tensorflow.python.data.experimental.service import _pywrap_server_lib
#      25 from tensorflow.python.data.experimental.service import _pywrap_utils_exp
# ---> 26 from tensorflow.python.data.ops import dataset_ops
#      27 from tensorflow.python.data.ops import options as options_lib
#      28 from tensorflow.python.data.ops import structured_function
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/data/ops/dataset_ops.py:34
#      32 from tensorflow.python.data.ops import dataset_autograph
#      33 from tensorflow.python.data.ops import debug_mode
# ---> 34 from tensorflow.python.data.ops import iterator_ops
#      35 from tensorflow.python.data.ops import options as options_lib
#      36 from tensorflow.python.data.ops import structured_function
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/data/ops/iterator_ops.py:45
#      43 from tensorflow.python.saved_model import nested_structure_coder
#      44 from tensorflow.python.trackable import base as trackable
# ---> 45 from tensorflow.python.training.saver import BaseSaverBuilder
#      46 from tensorflow.python.util import deprecation
#      47 from tensorflow.python.util.compat import collections_abc
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/training/saver.py:50
#      48 from tensorflow.python.saved_model.pywrap_saved_model import metrics
#      49 from tensorflow.python.trackable import base as trackable
# ---> 50 from tensorflow.python.training import py_checkpoint_reader
#      51 from tensorflow.python.training import training_util
#      52 from tensorflow.python.training.saving import saveable_object
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/training/py_checkpoint_reader.py:19
#      17 from tensorflow.python.framework import errors_impl
#      18 from tensorflow.python.util import compat
# ---> 19 from tensorflow.python.util._pywrap_checkpoint_reader import CheckpointReader
#      20 from tensorflow.python.util.tf_export import tf_export
#      23 def error_translator(e):
#
# SystemError: initialization of _pywrap_checkpoint_reader raised unreported exception

# %%
def save_data_pickle(file_path, data):
    with open(file_path, 'wb') as file:
        pickle.dump(data, file)

def load_data_pickle(file_path):
    with open(file_path, 'rb') as file:
        return pickle.load(file)

# %%
import requests

def send_telegram_message(message):
    bot_token = '797390018:AAHWSVCdBvXnERxnz4kI4ACvrfu_Rq7xLxc'
    chat_id = '626444855'
    
    response = requests.get(f'https://api.telegram.org/bot{bot_token}/sendMessage?chat_id={chat_id}&text={message}')
    
    if response.status_code == 200:
        print('Mensagem enviada com sucesso!')
    else:
        print(f'Falha ao enviar a mensagem. Código de status: {response.status_code}')

# %%
def augment_image_individually(X, Y, max_shift=8, max_rotation=1, brightness_range=0.5, num_augmentations=10, pct_noise=0.02):
    
    num_augmentations = 10
    X_data = []
    Y_data = []
    for original_frames, y in tqdm(zip(X, Y), total=len(X)):
        
        X_data.append(original_frames)
        Y_data.append(y)
               
        for _ in range(num_augmentations):
            augmented_frames = []
            for frame in original_frames:
                dx = np.random.randint(-max_shift, max_shift)
                angulo = np.random.uniform(-max_rotation, max_rotation)
                fator_brilho = np.random.uniform(1 - brightness_range, 1 + brightness_range)
                h_flip = np.random.choice([True, False])
                v_flip = np.random.choice([True, False])
                rotate = np.random.choice([0, 90, 180, 270])
                noise_factor = random.uniform(0, 1)
                pct_noise = noise_factor * pct_noise
                apply_blur = np.random.choice([True, False])
                shear_range = 0
                swap_channels = np.random.choice([True, False])
            
                augmented_frames.append(augment_image(frame, dx, angulo, fator_brilho, h_flip, v_flip, rotate, pct_noise,
                                                    apply_blur=apply_blur, shear_range=shear_range, swap_channels=swap_channels))
            x = np.array(augmented_frames)
            X_data.append(x)
            Y_data.append(y)
            
            
            
    return np.array(X_data), np.array(Y_data)

# %%
import requests

def send_telegram_image(image_path):
    bot_token = '797390018:AAHWSVCdBvXnERxnz4kI4ACvrfu_Rq7xLxc'
    chat_id = '626444855'
    
    # URL da API do Telegram para enviar fotos
    url = f'https://api.telegram.org/bot{bot_token}/sendPhoto'
    
    # Abrir a imagem no modo binário e enviá-la
    with open(image_path, 'rb') as image_file:
        response = requests.post(url, data={'chat_id': chat_id}, files={'photo': image_file})
    
    # Verificar a resposta
    if response.status_code == 200:
        print('Imagem enviada com sucesso!')
    else:
        print(f'Falha ao enviar a imagem. Código de status: {response.status_code}')

# %%
def send_telegram_file(file_path, caption=""):
    bot_token = '797390018:AAHWSVCdBvXnERxnz4kI4ACvrfu_Rq7xLxc'
    chat_id = '626444855'
    
    # URL da API do Telegram para enviar arquivos
    url = f'https://api.telegram.org/bot{bot_token}/sendDocument'
    
    # Abrir o arquivo no modo binário e enviá-lo
    with open(file_path, 'rb') as file:
        response = requests.post(url, data={'chat_id': chat_id, 'caption': caption}, files={'document': file})
    
    # Verificar a resposta
    if response.status_code == 200:
        print('Arquivo enviado com sucesso!')
    else:
        print(f'Falha ao enviar o arquivo. Código de status: {response.status_code}, Resposta: {response.text}')

# %%
frames_folder_path='frames'
egg_data_sheet_path='dados_ovos.xlsx'
final_frame_shape = (50, 50)
grayscale=False
possible_objective_columns = ['Massa Total Aferido','Clara','Gema','Casca','Gema + Clara']
# objective_columns = ['Massa Total Aferido','Clara','Gema','Casca','Gema + Clara']
objective_columns = ['Massa Total Aferido','Clara','Gema + Clara']
# objective_columns = ['Clara']


additional_feature_list = []

# %%
def select_frames_with_spacing(total_frames=36, num_selected_frames=8):
    """
    Seleciona `num_selected_frames` frames igualmente espaçados de um conjunto de `total_frames`.
    O ponto de partida é selecionado aleatoriamente e a contagem é circular se ultrapassar o limite.
    """
    start_index = random.randint(0, total_frames - 1)
    spacing = total_frames // num_selected_frames
    selected_indices = [(start_index + i * spacing) % total_frames for i in range(num_selected_frames)]
    return selected_indices

# %%
def load_frames(egg_index, colors=['green', 'red', 'blue', 'white'], videos=[1, 2], base_path='frames',
                resize_ratio=1.0, grayscale=False, max_frames_by_color=6, final_frame_shape=(100, 100), write_index=False):
    frames = []

    # Verifica se `videos` é um valor único ou uma lista
    if not isinstance(videos, list):
        videos = [videos]

    # Cria os caminhos dos vídeos
    videos_paths = []
    for i in videos:
        videos_folder_path = os.listdir(os.path.join(base_path, f'egg_{egg_index}'))
        videos_paths.append(videos_folder_path[i - 1])

    for video_path in videos_paths:
        for color in colors:
            path = os.path.join(base_path, f'egg_{egg_index}', video_path, color)
            frame_files = sorted(os.listdir(path))  # Ordena para manter a sequência

            if len(frame_files) < max_frames_by_color:
                raise ValueError(f"Número insuficiente de frames na cor {color} para o ovo {egg_index}.")

            # Seleciona índices de frames com espaçamento
            selected_indices = select_frames_with_spacing(len(frame_files), max_frames_by_color)
            window_frames = []

            for idx in selected_indices:
                frame_path = os.path.join(path, frame_files[idx])
                frame = cv2.imread(frame_path, cv2.IMREAD_COLOR)
                if resize_ratio != 1.0:
                    frame = cv2.resize(frame, None, fx=resize_ratio, fy=resize_ratio, interpolation=cv2.INTER_AREA)

                if grayscale:
                    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

                # Adiciona bordas pretas para tornar a imagem quadrada, se necessário
                width, height = 100, 100
                top = bottom = (height - frame.shape[0]) // 2
                left = right = (width - frame.shape[1]) // 2
                if (height - frame.shape[0]) % 2 != 0:
                    bottom += 1
                if (width - frame.shape[1]) % 2 != 0:
                    right += 1
                frame = cv2.copyMakeBorder(frame, top, bottom, left, right, cv2.BORDER_CONSTANT, value=[0, 0, 0])

                if final_frame_shape != frame.shape[:2]:
                    frame = cv2.resize(frame, final_frame_shape, interpolation=cv2.INTER_AREA)
                    
                if write_index:
                    # write idx in the middle of the frame
                    idx_text = f"{color}_{idx}"
                    cv2.putText(frame, idx_text, (0, frame.shape[0] // 2), cv2.FONT_HERSHEY_COMPLEX, 0.3, (255, 255, 255), 1)

                frames.append(frame)

            # frames.append(window_frames)

    return np.array(frames)

# %%
df_result = pd.read_excel(egg_data_sheet_path)
# Remove rows that column "100% - Massa Total Calc/Aferida" is > 0.01
df_result = df_result[df_result["100% - Massa Total Calc/Aferida"] <= 0.02]
# Remove rows that column "1 - Casca Aferida/Calculada" is > 0.05
# df_result = df_result[df_result['1 – Casca Aferida/Calculada'] <= 0.05]
# Separate columns Índice and Gema
df_result = df_result[["Índice"]+objective_columns]
# Delete row with Nan
df_result = df_result.dropna()
# Remove indice 476 because it has no frames
df_result = df_result[df_result['Índice']!= 476]
print(f"Len of dataset: {len(df_result)}")
df_result.head()
# Out:
# Len of dataset: 149
#    Índice  Massa Total Aferido  Clara  Gema + Clara
# 0       6                51.61  30.58         44.68
# 1       8                54.43  29.40         47.57
# 4      14                53.84  31.94         46.85
# 5      16                55.46  35.13         48.02
# 6      18                47.53  28.44         41.23

# %%
print(df_result['Índice'].unique())
# Out:
# [  6   8  14  16  18  20  22  27  29  35  39  41  47  52  54  58  64  68
#   70  72  74  86  90  92  98 101 103 107 109 111 115 117 119 121 125 127
#  129 131 133 135 137 139 141 143 145 147 149 155 157 159 163 165 167 204
#  212 214 221 227 229 231 233 235 237 239 241 243 251 253 255 261 263 265
#  267 269 271 273 277 285 287 289 293 295 299 301 303 307 309 311 313 315
#  317 319 321 323 325 404 406 408 410 412 414 418 420 422 424 434 436 438
#  440 442 446 448 450 454 456 458 460 462 468 470 478 480 488 496 498 502
#  504 506 510 512 514 518 618 620 622 624 626 628 630 632 634 638 640 654
#  656 660 662 664 672]

# %%
egg_indexes = []
for egg_index_path in os.listdir(frames_folder_path):
    egg_index = int(egg_index_path.split('_')[1])
    if egg_index in df_result['Índice'].values:
        egg_indexes.append(int(egg_index))
#remove index 476 because it has no frames
# egg_indexes.remove(476)
# egg_indexes.remove(127)
random.shuffle(egg_indexes)

# %%
invalid_amount = len(os.listdir(frames_folder_path)) - len(egg_indexes)
print(f"Valid eggs: {len(egg_indexes)}. Invalid eggs: {invalid_amount}. Total eggs: {len(os.listdir(frames_folder_path))}")
print(f"Valid eggs: {len(egg_indexes) / len(os.listdir(frames_folder_path)) * 100:.2f}%. Invalid eggs: {invalid_amount / len(os.listdir(frames_folder_path)) * 100:.2f}%")
# Out:
# Valid eggs: 149. Invalid eggs: 80. Total eggs: 229
# Valid eggs: 65.07%. Invalid eggs: 34.93%

# %%
# Split the eggs into train, validation and test sets
train_split = 0.6
validation_split = 0.2
test_split = 0.2

train_indexes = egg_indexes[:int(len(egg_indexes) * train_split)]
validation_indexes = egg_indexes[int(len(egg_indexes) * train_split):int(len(egg_indexes) * (train_split + validation_split))]
test_indexes = egg_indexes[int(len(egg_indexes) * (train_split + validation_split)):]
test_indexes.sort()

# %%
#index amount by set
print(f"Train: {len(train_indexes)}. Validation: {len(validation_indexes)}. Test: {len(test_indexes)}")
# Out:
# Train: 89. Validation: 30. Test: 30

# %%
colors = ['blue','green','red', 'white']
# colors = ['white']
max_frames_by_color = 8
num_originals_per_egg = 30

# %%
frames_example = load_frames(egg_index=410, colors=colors, videos=[1,2], base_path=frames_folder_path, 
                             resize_ratio=0.1, grayscale=grayscale, max_frames_by_color=max_frames_by_color, 
                             final_frame_shape=final_frame_shape, write_index=True)

# %%
frames_example.shape
# Out:
# (64, 50, 50, 3)

# %%
import matplotlib.pyplot as plt

# Número de frames no `frames_example`
num_frames = len(frames_example)

# Configurações para exibir 4 imagens por linha
cols = 4
rows = (num_frames + cols - 1) // cols  # Calcula o número necessário de linhas

# Configura o tamanho da figura para garantir que as imagens não sejam encolhidas
plt.figure(figsize=(cols * 4, rows * 4))  # Ajuste o multiplicador (4) para alterar o tamanho final

# Plota cada frame
for i in range(num_frames):
    plt.subplot(rows, cols, i + 1)
    plt.imshow(frames_example[i])
    plt.xticks([])
    plt.yticks([])

plt.show()

# %%
grayscale
# Out:
# False

# %%
if grayscale:
  num_frames, altura_frame, largura_frame = frames_example.shape
  channels = 1
else:
  num_frames, altura_frame, largura_frame, channels = frames_example.shape
print(frames_example.shape)
# Out:
# (64, 50, 50, 3)

# %%
image = cv2.imread('Screenshot from 2024-11-15 03-17-08.png')

num_pixels = int(image.shape[0] * image.shape[1] * 0.02)
y_coords = np.random.randint(0, image.shape[0], num_pixels)
x_coords = np.random.randint(0, image.shape[1], num_pixels)
if len(image.shape) == 3:
    noise = np.random.randint(0, 256, (num_pixels, image.shape[2]), dtype=np.uint)
else:
    noise = np.random.randint(0, 256, num_pixels, dtype=np.uint8)
image[y_coords, x_coords] = noise
cv2.imwrite('a.png', image)
# Out:
# True

# %%
def augment_image(image, dx, angulo, fator_brilho, h_flip, v_flip, rotate, pct_noise,
                  apply_blur=False, shear_range=False, swap_channels=False):
    altura, largura = image.shape[:2]
    
    # Adição de ruído
    if pct_noise:
        num_pixels = int(image.shape[0] * image.shape[1] * pct_noise)
        y_coords = np.random.randint(0, image.shape[0], num_pixels)
        x_coords = np.random.randint(0, image.shape[1], num_pixels)
        if len(image.shape) == 3:
            noise = np.random.randint(0, 256, (num_pixels, image.shape[2]), dtype=np.uint)
        else:
            noise = np.random.randint(0, 256, num_pixels, dtype=np.uint8)
        image[y_coords, x_coords] = noise
    
    # Translação
    M_shift = np.float32([[1, 0, dx], [0, 1, 0]])
    image = cv2.warpAffine(image, M_shift, (largura, altura))
    
    # Flip horizontal e vertical
    if h_flip:
        image = cv2.flip(image, 1)
    if v_flip:
        image = cv2.flip(image, 0)
    
    # Rotação
    if rotate == 90:
        image = cv2.transpose(image)
        image = cv2.flip(image, 1)
    elif rotate == 180:
        image = cv2.flip(image, -1)
    elif rotate == 270:
        image = cv2.transpose(image)
        image = cv2.flip(image, 0)
    
    # Ajuste de brilho
    image = cv2.convertScaleAbs(image, alpha=fator_brilho)
    
    if shear_range:
        altura, largura = image.shape[:2]
        shear_value = np.random.uniform(-shear_range, shear_range)
        M = np.array([[1, shear_value, 0], [0, 1, 0]], dtype=np.float32)
        image = cv2.warpAffine(image, M, (largura, altura))

    # Aplicar desfoque
    if apply_blur:
        cv2.GaussianBlur(image, (3,3), 0)
        

    # Inversão de canais de cor
    if swap_channels:
        cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    return image

# %%
def load_all_data(indexes, colors, videos, base_path, resize_ratio, df_result,
                  num_originals_per_egg=num_originals_per_egg, grayscale=False, augment=False, max_shift=5, max_rotation=360,
                  brightness_range=0.5, max_amount=None, num_augmentations=8, shuffle=True, max_frames_by_color=max_frames_by_color, 
                  pct_noise=0.02, shuffle_frames=True, additional_feature_list=None, final_frame_shape=(100,100)):
    X_data = []
    Y_data = []
    X_additional_feature = []

    for egg_index in tqdm(indexes[:max_amount]):
        try:
            for _ in range(num_originals_per_egg):
                original_frames = load_frames(egg_index, colors, videos, base_path, resize_ratio,
                                              grayscale=grayscale, max_frames_by_color=max_frames_by_color, final_frame_shape=final_frame_shape)
                obj_value = df_result[df_result['Índice'] == egg_index][objective_columns].iloc[0]
                if additional_feature_list:
                    additional_feature = df_result[df_result['Índice'] == egg_index][additional_feature_list].iloc[0]
                else:
                    additional_feature = 0

                # Adicionar os arranjos originais
                X_data.append(original_frames)
                Y_data.append(obj_value)
                X_additional_feature.append(additional_feature)

                if augment:
                    for _ in range(num_augmentations):
                        augmented_frames = []
                        for frame in original_frames:
                            dx = np.random.randint(-max_shift, max_shift)
                            angulo = np.random.uniform(-max_rotation, max_rotation)
                            fator_brilho = np.random.uniform(1 - brightness_range, 1 + brightness_range)
                            h_flip = np.random.choice([True, False])
                            v_flip = np.random.choice([True, False])
                            rotate = np.random.choice([0, 90, 180, 270])
                            noise_factor = random.uniform(0, 1)
                            pct_noise = noise_factor * pct_noise
                            apply_blur = np.random.choice([True, False])
                            shear_range = 0
                            swap_channels = np.random.choice([True, False])

                            augmented_frames.append(augment_image(frame, dx, angulo, fator_brilho, h_flip, v_flip, rotate, pct_noise,
                                                                  apply_blur=apply_blur, shear_range=shear_range, swap_channels=swap_channels))
                        x = np.array(augmented_frames)
                        
                        # shuffle np.array para fazer o shuffle
                        if shuffle_frames:
                            random.shuffle(x)
                        X_data.append(x)
                        Y_data.append(obj_value)
                        X_additional_feature.append(additional_feature)

        except Exception as e:
            print(f"Erro ao carregar ovo {egg_index}: {e}")

    if shuffle:
        data = list(zip(X_data, Y_data, X_additional_feature))
        random.shuffle(data)
        X_data, Y_data, X_additional_feature = zip(*data)

    return np.array(X_data), np.array(Y_data), np.array(X_additional_feature)

# %%
# # Carregando dados para treino, validação e teste
max_amount=None
num_augmentations=10
max_frames_by_color = 8
num_originals_per_egg = 30

# %%
X_train, Y_train, X_train_additional = load_all_data(train_indexes, colors, [1, 2], frames_folder_path, 0.1, df_result, 
                                                     num_originals_per_egg=num_originals_per_egg, grayscale=grayscale, augment=True, 
                                                     max_shift=8, max_rotation=1, brightness_range=0.5, 
                                                     max_amount=max_amount, num_augmentations=0, shuffle=True,
                                                     max_frames_by_color=max_frames_by_color, pct_noise=0.02,shuffle_frames=True, final_frame_shape=final_frame_shape)

X_val, Y_val, X_val_additional = load_all_data(validation_indexes, colors, [1, 2], frames_folder_path, 0.1, df_result, 
                                               num_originals_per_egg=num_originals_per_egg, grayscale=grayscale, augment=True, 
                                               max_shift=8, max_rotation=1, brightness_range=0.5, 
                                               max_amount=max_amount, num_augmentations=0, shuffle=True,
                                               max_frames_by_color=max_frames_by_color, pct_noise=0.02,shuffle_frames=True, final_frame_shape=final_frame_shape)

X_test, Y_test, X_test_additional = load_all_data(test_indexes, colors, [1, 2], frames_folder_path, 0.1, df_result, 
                                                  num_originals_per_egg=num_originals_per_egg, grayscale=grayscale, augment=False, 
                                                  shuffle=False, max_frames_by_color=max_frames_by_color,
                                                  max_amount=max_amount, final_frame_shape=final_frame_shape)

# %%
# #save arrays
# np.save(f'X_train_sem_aumentacao{"_colorido" if not grayscale else ""}.npy', X_train)
# np.save(f'X_train_additional_sem_aumentacao{"_colorido" if not grayscale else ""}.npy', X_train_additional)
# np.save(f'Y_train_sem_aumentacao{"_colorido" if not grayscale else ""}.npy', Y_train)

# np.save(f'X_val_sem_aumentacao{"_colorido" if not grayscale else ""}.npy', X_val)
# np.save(f'X_val_additional_sem_aumentacao{"_colorido" if not grayscale else ""}.npy', X_val_additional)
# np.save(f'Y_val_sem_aumentacao{"_colorido" if not grayscale else ""}.npy', Y_val)

# np.save(f'X_test_sem_aumentacao{"_colorido" if not grayscale else ""}.npy', X_test)
# np.save(f'X_test_additional_sem_aumentacao{"_colorido" if not grayscale else ""}.npy', X_test_additional)
# np.save(f'Y_test_sem_aumentacao{"_colorido" if not grayscale else ""}.npy', Y_test)

# %%
# X_train = np.load(f'X_train_sem_aumentacao{"_colorido" if not grayscale else ""}.npy')
# X_train_additional = np.load(f'X_train_additional_sem_aumentacao{"_colorido" if not grayscale else ""}.npy')
# Y_train = np.load(f'Y_train_sem_aumentacao{"_colorido" if not grayscale else ""}.npy')

# X_val = np.load(f'X_val_sem_aumentacao{"_colorido" if not grayscale else ""}.npy')
# X_val_additional = np.load(f'X_val_additional_sem_aumentacao{"_colorido" if not grayscale else ""}.npy')
# Y_val = np.load(f'Y_val_sem_aumentacao{"_colorido" if not grayscale else ""}.npy')

# X_test = np.load(f'X_test_sem_aumentacao{"_colorido" if not grayscale else ""}.npy')
# X_test_additional = np.load(f'X_test_additional_sem_aumentacao{"_colorido" if not grayscale else ""}.npy')
# Y_test = np.load(f'Y_test_sem_aumentacao{"_colorido" if not grayscale else ""}.npy')

# %%
# #print len train_indexes, len validation_indexes, len test_indexes
# print(f"X_train_indexes: {len(train_indexes)}, X_val_indexes: {len(validation_indexes)}, X_test_indexes: {len(test_indexes)}")
# print(f"X_train shape: {X_train.shape}, X_val shape: {X_val.shape}, X_test shape: {X_test.shape}")

# %%
# Join X-train e X_val embaralha e depois X_train e 80% e X_val e 20%


new_X = np.concatenate((X_train, X_val), axis=0)
new_Y = np.concatenate((Y_train, Y_val), axis=0)


from sklearn.model_selection import train_test_split

# Divida 80% para treino e 20% para validação
X_train, X_val, Y_train, Y_val = train_test_split(new_X, new_Y, test_size=0.2, random_state=2024)

del(new_X, new_Y)

# %%
#print len train_indexes, len validation_indexes, len test_indexes
print(f"X_train_indexes: {len(train_indexes)}, X_val_indexes: {len(validation_indexes)}, X_test_indexes: {len(test_indexes)}")
print(f"X_train shape: {X_train.shape}, X_val shape: {X_val.shape}, X_test shape: {X_test.shape}")

# %%
X_train, Y_train = augment_image_individually(X_train, Y_train, max_shift=8, max_rotation=1, brightness_range=0.5,
                                            num_augmentations=10, pct_noise=0.02)
X_val, Y_val = augment_image_individually(X_val, Y_val, max_shift=8, max_rotation=1, brightness_range=0.5,
                                            num_augmentations=10, pct_noise=0.02)

# %%
# #save arrays
# np.save(f'X_train_com_aumentacao_misturado{"_colorido" if not grayscale else ""}.npy', X_train)
# np.save(f'Y_train_com_aumentacao_misturado{"_colorido" if not grayscale else ""}.npy', Y_train)

# np.save(f'X_val_com_aumentacao_misturado{"_colorido" if not grayscale else ""}.npy', X_val)
# np.save(f'Y_val_com_aumentacao_misturado{"_colorido" if not grayscale else ""}.npy', Y_val)

# %%
# X_train = np.load(f'X_train_com_aumentacao_misturado{"_colorido" if not grayscale else ""}.npy')
# Y_train = np.load(f'Y_train_com_aumentacao_misturado{"_colorido" if not grayscale else ""}.npy')

# X_val = np.load(f'X_val_com_aumentacao_misturado{"_colorido" if not grayscale else ""}.npy')
# Y_val = np.load(f'Y_val_com_aumentacao_misturado{"_colorido" if not grayscale else ""}.npy')

# X_test = np.load(f'X_test_sem_aumentacao{"_colorido" if not grayscale else ""}.npy')
# Y_test = np.load(f'Y_test_sem_aumentacao{"_colorido" if not grayscale else ""}.npy')

# %%
#print len train_indexes, len validation_indexes, len test_indexes
print(f"X_train_indexes: {len(train_indexes)}, X_val_indexes: {len(validation_indexes)}, X_test_indexes: {len(test_indexes)}")
print(f"X_train shape: {X_train.shape}, X_val shape: {X_val.shape}, X_test shape: {X_test.shape}")
# Out:
# X_train_indexes: 89, X_val_indexes: 30, X_test_indexes: 30
# X_train shape: (31416, 64, 50, 50, 3), X_val shape: (7854, 64, 50, 50, 3), X_test shape: (900, 64, 50, 50, 3)

# %%
for i in range(len(X_train)):
    #shuffle frames
    X_train[i] = random.sample(list(X_train[i]), len(X_train[i]))
for i in range(len(X_val)):
    #shuffle frames
    X_val[i] = random.sample(list(X_val[i]), len(X_val[i]))
  
for i in range(len(X_test)):
    #shuffle frames
    X_test[i] = random.sample(list(X_test[i]), len(X_test[i]))

# %%
objective_columns
# Out:
# ['Massa Total Aferido', 'Clara', 'Gema + Clara']

# %%
print(f"X_train shape: {X_train.shape}, Y_train shape: {Y_train.shape}")
print(f"X_val shape: {X_val.shape}, Y_val shape: {Y_val.shape}")
print(f"X_test shape: {X_test.shape}, Y_test shape: {Y_test.shape}")
# Out:
# X_train shape: (31416, 64, 50, 50, 3), Y_train shape: (31416, 3)
# X_val shape: (7854, 64, 50, 50, 3), Y_val shape: (7854, 3)
# X_test shape: (900, 64, 50, 50, 3), Y_test shape: (900, 3)

# %%
len(test_indexes)
# Out:
# 30

# %%
# Salvar cada imagem do x_train[X]
random_index = random.randint(0, len(X_train))
# random_index = 229
if os.path.exists('frames_train'):
    os.system('rm -rf frames_train')
os.makedirs('frames_train', exist_ok=True)
print("random_index", random_index)
for i, image in enumerate(X_train[random_index]):
    cv2.imwrite(f'frames_train/{random_index}_{i}.jpg', image)
# Out:
# random_index 22882

# %%
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, concatenate, LSTM, TimeDistributed, Dropout, RepeatVector, Reshape, BatchNormalization
from keras.models import Model 
from keras.regularizers import l2

def create_model(num_frames, altura_frame, largura_frame, channels):
    input_shape = (num_frames, altura_frame, largura_frame, channels)

    input_layer = Input(shape=input_shape)
    x = TimeDistributed(Conv2D(16, (3, 3), activation='relu'))(input_layer)
    x = TimeDistributed(MaxPooling2D((2, 2)))(x)
    # x = TimeDistributed(Dropout(0.2))(x)


    # Terceira camada convolucional
    x = TimeDistributed(Conv2D(8, (3, 3), activation='relu'))(x)
    x = TimeDistributed(MaxPooling2D((2, 2)))(x)
    # x = TimeDistributed(Dropout(0.2))(x)
    
    # x = TimeDistributed(Flatten())(x)

    x = Flatten()(x)

    # Fully Connected Layers
    # x = Dense(64, activation='relu', kernel_regularizer=l2(0.001))(x)
    # x = BatchNormalization()(x)
    x = Dense(32, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)  # Adicionar Dropout nas camadas densas
    x = Dense(16, activation='relu')(x)
    # x = Dense(8, activation='relu')(x)
    x = Dense(len(objective_columns))(x)
    
    # Modifique esta linha para incluir ambos os inputs
    model = Model(inputs=input_layer, outputs=x)

    return model

# %%
# Calculando a média dos valores reais
real_mean = Y_val.mean()
mae_mean = abs(Y_val - real_mean).mean()
print(f"Média real: {real_mean:.4f}. MAE da média: {mae_mean:.4f}")
# Out:
# Média real: 44.4330. MAE da média: 9.1330

# %%
# from keras.utils import plot_model

# plot_model(
#     model,
#     to_file="model.png",
#     show_shapes=True,
#     show_dtype=False,
#     show_layer_names=False,
#     rankdir="TB",
#     expand_nested=True,
#     dpi=200,
#     show_layer_activations=True,
#     show_trainable=False,
# )

# %%
objective_columns
# Out:
# ['Massa Total Aferido', 'Clara', 'Gema + Clara']

# %%
#load keras model
from keras.models import load_model
# model = load_model('model_best_all.keras')
# model = load_model('model_best_total_mass_mae_sam_grayscale.keras')
model = create_model(num_frames, altura_frame, largura_frame, channels)
# Out:
# 2024-11-17 12:45:08.877218: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-17 12:45:08.909961: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-17 12:45:08.910166: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-17 12:45:08.912253: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-17 12:45:08.912477: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-17 12:45:08.912563: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-17 12:45:08.969745: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-17 12:45:08.969861: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-17 12:45:08.969941: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-17 12:45:08.970015: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21124 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
from keras.callbacks import Callback
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error, r2_score
from datetime import datetime

class TestEvaluationCallback(Callback):
    def __init__(self, model, X_test, Y_test, objective_columns, interval=10):
        super(TestEvaluationCallback, self).__init__()
        self.model = model
        self.X_test = X_test
        self.Y_test = Y_test
        self.objective_columns = objective_columns
        self.interval = interval

    def on_epoch_end(self, epoch, logs=None):
        # Checa se é uma época múltipla de "interval" (exemplo: 10)
        if epoch % self.interval == 0 and epoch != 0:
            print(f"\nEvaluating on test set at epoch {epoch}")
            send_telegram_message(f"Test metrics at epoch {epoch}")
            # Fazer previsões
            Y_pred = self.model.predict(self.X_test)

            # Inicializar um dicionário para armazenar DataFrames separados para cada coluna de saída
            result_dfs = {}
            metrics = {}

            # Iterar sobre cada coluna de saída e preencher os resultados em DataFrames separados
            mape_str = ''
            for idx, col_name in enumerate(self.objective_columns):
                result = {
                    "real": self.Y_test[:, idx],
                    "predict": Y_pred[:, idx],
                    "difference": abs(Y_pred[:, idx] - self.Y_test[:, idx])
                }
                # Criar DataFrame para a saída específica
                result_dfs[col_name] = pd.DataFrame(result)

                # Calcular as métricas
                mae = mean_absolute_error(result_dfs[col_name]['real'], result_dfs[col_name]['predict'])
                mape = mean_absolute_percentage_error(result_dfs[col_name]['real'], result_dfs[col_name]['predict'])
                mse = mean_squared_error(result_dfs[col_name]['real'], result_dfs[col_name]['predict'])
                r2 = r2_score(result_dfs[col_name]['real'], result_dfs[col_name]['predict'])

                # Armazenar as métricas no dicionário
                metrics[col_name] = {
                    'MAE': mae,
                    'MAPE': mape,
                    'MSE': mse,
                    'R2': r2
                }
                
                send_telegram_message(f"{col_name} MAE: {mae:.4f}, MAPE: {mape:.4f}, MSE: {mse:.4f}, R2: {r2:.4f}")


            # Se desejar, pode enviar as métricas ou salvar em um arquivo
            # send_telegram_message(f"Métricas: {metrics_df.to_string()}")
            
            #se r2 da clara ser maior que 0,7 salva o modelo sendo modelo_{datetime}_{epoch}.keras
            
            if metrics['Clara']['R2'] > 0.7:
                model_path = f'model_{epoch}.keras'
                model.save(model_path)
                send_telegram_message(f"Modelo salvo com R2 maior que 0.7: model_{datetime}_{epoch}.keras")
                send_telegram_file(model_path)
            
# Criar a instância do callback com os parâmetros adequados
test_evaluation_callback = TestEvaluationCallback(
    model=model,
    X_test=X_test,
    Y_test=Y_test,
    objective_columns=objective_columns,
    interval=25
)

# %%
class SaveHistoryToExcelCallback(Callback):
    def __init__(self, filepath, save_freq=100):
        super(SaveHistoryToExcelCallback, self).__init__()
        self.filepath = filepath
        self.save_freq = save_freq
        self.history_data = {}

    def on_epoch_end(self, epoch, logs=None):
        # Adiciona os logs da época atual ao histórico
        for key, value in logs.items():
            if key not in self.history_data:
                self.history_data[key] = []
            self.history_data[key].append(value)

        # Salva o histórico a cada `save_freq` épocas
        if (epoch + 1) % self.save_freq == 0:
            df = pd.DataFrame(self.history_data)
            df.to_excel(self.filepath, index=False)

# %%
from datetime import datetime
send_telegram_message(f"Treinamento iniciado em {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# Mensagem enviada com sucesso!

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
from keras.callbacks import ReduceLROnPlateau
from keras.optimizers import Adam


# lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=1e-6, verbose=1)

history = None

batch_size = 50
epochs = 10000
patience = 100

# def weighted_mape_loss(y_true, y_pred):
#     weights = tf.constant([0.25, 0.5, 0.25])  # Pesos normalizados
#     mape = tf.abs((y_true - y_pred) / tf.clip_by_value(tf.abs(y_true), 1e-9, tf.reduce_max(y_true)))
#     weighted_mape = mape * weights
#     return tf.reduce_mean(weighted_mape)
# model.compile(optimizer=Adam(learning_rate=0.001), 
#               loss=weighted_mape_loss, 
#               metrics=['mape'])

# model.compile(optimizer='adam', loss='mape', metrics=['mae','mape'])
model.compile(optimizer=Adam(lr=0.0001), loss='mape', metrics=['mape'])


# Caminho do arquivo onde você deseja salvar o modelo
model_checkpoint_path = f'model_best_total_mass_mae_sam_{"grayscale" if grayscale else "color"}.keras'

# Criar o callback ModelCheckpoint
model_checkpoint_callback = ModelCheckpoint(
    model_checkpoint_path,
    monitor='val_loss', 
    verbose=1,
    save_best_only=True,
    mode='min'
)

# Criar o callback EarlyStopping
early_stopping_callback = EarlyStopping(
    monitor='val_loss',
    patience=patience,  # Número de épocas sem melhoria após o qual o treinamento será interrompido
    verbose=1,
    mode='min',
    restore_best_weights=True  # Restaura os pesos do melhor modelo encontrado
)

history_path = f'model_history_{datetime.now().strftime("%d-%m-%Y_%H%M%S")}.xlsx'
save_history_callback = SaveHistoryToExcelCallback(filepath=history_path, save_freq=10)


# Treinamento do modelo com os callbacks
history = model.fit(
    X_train,
    Y_train, 
    steps_per_epoch=int(len(X_train)/4/batch_size),
    batch_size=batch_size, 
    epochs=epochs, 
    validation_data=(X_val, Y_val),
    validation_steps=int(len(X_val)/4/batch_size),
    callbacks=[model_checkpoint_callback, early_stopping_callback, TensorBoard(log_dir='./logs', histogram_freq=1), test_evaluation_callback, save_history_callback],
    
)

# tensorboard --logdir logs --bind_all
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/10000
# 2024-11-17 12:45:38.271613: W external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:225] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.9
# 2024-11-17 12:45:38.271638: W external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:228] Used ptxas at ptxas
# 2024-11-17 12:45:38.271744: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-17 12:45:38.271762: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-17 12:45:38.272393: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-17 12:45:38.272412: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-17 12:45:38.272428: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-17 12:45:38.272445: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-17 12:45:38.272463: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-17 12:45:38.272476: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-17 12:45:39.152037: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8902
# 2024-11-17 12:45:39.171733: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-17 12:45:39.172395: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-17 12:45:39.172889: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-17 12:45:39.173201: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-17 12:45:39.174237: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-17 12:45:39.178782: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-17 12:45:39.178809: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-17 12:45:39.178829: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-17 12:45:39.259025: W external/local_xla/xla/stream_executor/gpu/redzone_allocator.cc:322] UNIMPLEMENTED: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2024-11-17 12:45:41.067280: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-17 12:45:41.147472: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-17 12:45:41.147618: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-17 12:45:41.147663: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-17 12:45:41.149109: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-17 12:45:41.149137: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-17 12:45:41.150203: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-17 12:45:41.150225: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-17 12:45:41.153471: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-17 12:45:41.306752: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-17 12:45:41.426702: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-17 12:45:41.426838: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-17 12:45:41.426988: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-17 12:45:41.428098: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-17 12:45:41.428124: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-17 12:45:41.428331: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-17 12:45:41.428439: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-17 12:45:41.429421: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-17 12:45:41.429684: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-17 12:45:41.691630: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-17 12:45:41.748431: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-17 12:45:41.764978: I external/local_xla/xla/service/service.cc:168] XLA service 0x7c228047c7f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-11-17 12:45:41.765008: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2024-11-17 12:45:41.769572: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731858341.805800  864042 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#   6/157 [>.............................] - ETA: 46s - loss: 100.4164 - mape: 100.4164WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1159s vs `on_train_batch_end` time: 0.1620s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1159s vs `on_train_batch_end` time: 0.1620s). Check your callbacks.
# 157/157 [==============================] - ETA: 0s - loss: 92.1067 - mape: 92.1067
# Epoch 1: val_loss improved from inf to 63.60169, saving model to model_best_total_mass_mae_sam_color.keras
# 157/157 [==============================] - 71s 387ms/step - loss: 92.1067 - mape: 92.1067 - val_loss: 63.6017 - val_mape: 63.6017
# Epoch 2/10000
# 157/157 [==============================] - ETA: 0s - loss: 53.6770 - mape: 53.6770
# Epoch 2: val_loss improved from 63.60169 to 33.89429, saving model to model_best_total_mass_mae_sam_color.keras
# 157/157 [==============================] - 54s 344ms/step - loss: 53.6770 - mape: 53.6770 - val_loss: 33.8943 - val_mape: 33.8943
# Epoch 3/10000
# 157/157 [==============================] - ETA: 0s - loss: 20.6395 - mape: 20.6395
# Epoch 3: val_loss improved from 33.89429 to 17.01497, saving model to model_best_total_mass_mae_sam_color.keras
# 157/157 [==============================] - 54s 342ms/step - loss: 20.6395 - mape: 20.6395 - val_loss: 17.0150 - val_mape: 17.0150
# Epoch 4/10000
# 157/157 [==============================] - ETA: 0s - loss: 12.0251 - mape: 12.0251
# Epoch 4: val_loss improved from 17.01497 to 14.76628, saving model to model_best_total_mass_mae_sam_color.keras
# 157/157 [==============================] - 54s 343ms/step - loss: 12.0251 - mape: 12.0251 - val_loss: 14.7663 - val_mape: 14.7663
# Epoch 5/10000
# 157/157 [==============================] - ETA: 0s - loss: 9.9187 - mape: 9.9187
# Epoch 5: val_loss improved from 14.76628 to 7.04077, saving model to model_best_total_mass_mae_sam_color.keras
# 157/157 [==============================] - 56s 342ms/step - loss: 9.9187 - mape: 9.9187 - val_loss: 7.0408 - val_mape: 7.0408
# Epoch 6/10000
# 157/157 [==============================] - ETA: 0s - loss: 9.4347 - mape: 9.4347
# Epoch 6: val_loss improved from 7.04077 to 4.51334, saving model to model_best_total_mass_mae_sam_color.keras
# 157/157 [==============================] - 53s 340ms/step - loss: 9.4347 - mape: 9.4347 - val_loss: 4.5133 - val_mape: 4.5133
# Epoch 7/10000
# 157/157 [==============================] - ETA: 0s - loss: 8.9579 - mape: 8.9579
# Epoch 7: val_loss improved from 4.51334 to 4.01914, saving model to model_best_total_mass_mae_sam_color.keras
# 157/157 [==============================] - 54s 342ms/step - loss: 8.9579 - mape: 8.9579 - val_loss: 4.0191 - val_mape: 4.0191
# Epoch 8/10000
# 157/157 [==============================] - ETA: 0s - loss: 8.8154 - mape: 8.8154
# Epoch 8: val_loss did not improve from 4.01914 of epoch 7
# 157/157 [==============================] - 54s 342ms/step - loss: 8.8154 - mape: 8.8154 - val_loss: 4.4753 - val_mape: 4.4753
# Epoch 9/10000
# 157/157 [==============================] - ETA: 0s - loss: 8.3281 - mape: 8.3281
# Epoch 9: val_loss did not improve from 4.01914 of epoch 7
# 157/157 [==============================] - 53s 340ms/step - loss: 8.3281 - mape: 8.3281 - val_loss: 4.4777 - val_mape: 4.4777
# Epoch 10/10000
# 157/157 [==============================] - ETA: 0s - loss: 8.2935 - mape: 8.2935
# Epoch 10: val_loss improved from 4.01914 to 3.29496, saving model to model_best_total_mass_mae_sam_color.keras
# 157/157 [==============================] - 54s 343ms/step - loss: 8.2935 - mape: 8.2935 - val_loss: 3.2950 - val_mape: 3.2950
# Epoch 11/10000
# 157/157 [==============================] - ETA: 0s - loss: 8.1948 - mape: 8.1948
# Epoch 11: val_loss did not improve from 3.29496 of epoch 10
# 157/157 [==============================] - 53s 340ms/step - loss: 8.1948 - mape: 8.1948 - val_loss: 4.3049 - val_mape: 4.3049
# Epoch 12/10000
# 157/157 [==============================] - ETA: 0s - loss: 7.9470 - mape: 7.9470
# Epoch 12: val_loss did not improve from 3.29496 of epoch 10
# 157/157 [==============================] - 53s 338ms/step - loss: 7.9470 - mape: 7.9470 - val_loss: 6.1508 - val_mape: 6.1508
# Epoch 13/10000
# 157/157 [==============================] - ETA: 0s - loss: 7.6751 - mape: 7.6751
# Epoch 13: val_loss did not improve from 3.29496 of epoch 10
# 157/157 [==============================] - 53s 338ms/step - loss: 7.6751 - mape: 7.6751 - val_loss: 4.1390 - val_mape: 4.1390
# Epoch 14/10000
# 157/157 [==============================] - ETA: 0s - loss: 7.6051 - mape: 7.6051
# Epoch 14: val_loss did not improve from 3.29496 of epoch 10
# 157/157 [==============================] - 53s 339ms/step - loss: 7.6051 - mape: 7.6051 - val_loss: 3.4173 - val_mape: 3.4173
# Epoch 15/10000
# 157/157 [==============================] - ETA: 0s - loss: 7.4411 - mape: 7.4411
# Epoch 15: val_loss did not improve from 3.29496 of epoch 10
# 157/157 [==============================] - 54s 341ms/step - loss: 7.4411 - mape: 7.4411 - val_loss: 3.7293 - val_mape: 3.7293
# Epoch 16/10000
# 157/157 [==============================] - ETA: 0s - loss: 7.4149 - mape: 7.4149
# Epoch 16: val_loss did not improve from 3.29496 of epoch 10
# 157/157 [==============================] - 53s 341ms/step - loss: 7.4149 - mape: 7.4149 - val_loss: 3.9449 - val_mape: 3.9449
# Epoch 17/10000
# 157/157 [==============================] - ETA: 0s - loss: 7.4024 - mape: 7.4024
# Epoch 17: val_loss improved from 3.29496 to 2.87923, saving model to model_best_total_mass_mae_sam_color.keras
# 157/157 [==============================] - 53s 338ms/step - loss: 7.4024 - mape: 7.4024 - val_loss: 2.8792 - val_mape: 2.8792
# Epoch 18/10000
# 157/157 [==============================] - ETA: 0s - loss: 7.2579 - mape: 7.2579
# Epoch 18: val_loss did not improve from 2.87923 of epoch 17
# 157/157 [==============================] - 53s 340ms/step - loss: 7.2579 - mape: 7.2579 - val_loss: 3.7491 - val_mape: 3.7491
# Epoch 19/10000
# 157/157 [==============================] - ETA: 0s - loss: 7.1213 - mape: 7.1213
# Epoch 19: val_loss did not improve from 2.87923 of epoch 17
# 157/157 [==============================] - 54s 343ms/step - loss: 7.1213 - mape: 7.1213 - val_loss: 4.1589 - val_mape: 4.1589
# Epoch 20/10000
# 157/157 [==============================] - ETA: 0s - loss: 6.9536 - mape: 6.9536
# Epoch 20: val_loss did not improve from 2.87923 of epoch 17
# 157/157 [==============================] - 53s 341ms/step - loss: 6.9536 - mape: 6.9536 - val_loss: 3.2706 - val_mape: 3.2706
# Epoch 21/10000
# 157/157 [==============================] - ETA: 0s - loss: 6.9903 - mape: 6.9903
# Epoch 21: val_loss did not improve from 2.87923 of epoch 17
# 157/157 [==============================] - 53s 337ms/step - loss: 6.9903 - mape: 6.9903 - val_loss: 3.7465 - val_mape: 3.7465
# Epoch 22/10000
# 157/157 [==============================] - ETA: 0s - loss: 6.8263 - mape: 6.8263
# Epoch 22: val_loss did not improve from 2.87923 of epoch 17
# 157/157 [==============================] - 53s 338ms/step - loss: 6.8263 - mape: 6.8263 - val_loss: 4.1513 - val_mape: 4.1513
# Epoch 23/10000
# 157/157 [==============================] - ETA: 0s - loss: 6.7940 - mape: 6.7940
# Epoch 23: val_loss did not improve from 2.87923 of epoch 17
# 157/157 [==============================] - 53s 339ms/step - loss: 6.7940 - mape: 6.7940 - val_loss: 3.2411 - val_mape: 3.2411
# Epoch 24/10000
# 157/157 [==============================] - ETA: 0s - loss: 6.6435 - mape: 6.6435
# Epoch 24: val_loss did not improve from 2.87923 of epoch 17
# 157/157 [==============================] - 53s 337ms/step - loss: 6.6435 - mape: 6.6435 - val_loss: 2.9486 - val_mape: 2.9486
# Epoch 25/10000
# 157/157 [==============================] - ETA: 0s - loss: 6.5649 - mape: 6.5649
# Epoch 25: val_loss did not improve from 2.87923 of epoch 17
# 157/157 [==============================] - 53s 336ms/step - loss: 6.5649 - mape: 6.5649 - val_loss: 2.9678 - val_mape: 2.9678
# Epoch 26/10000
# 157/157 [==============================] - ETA: 0s - loss: 6.5609 - mape: 6.5609
# Epoch 26: val_loss improved from 2.87923 to 2.69865, saving model to model_best_total_mass_mae_sam_color.keras
#
# Evaluating on test set at epoch 25
# Mensagem enviada com sucesso!
# 29/29 [==============================] - 3s 58ms/step
# Mensagem enviada com sucesso!
# Mensagem enviada com sucesso!
# Mensagem enviada com sucesso!
# 157/157 [==============================] - 60s 385ms/step - loss: 6.5609 - mape: 6.5609 - val_loss: 2.6987 - val_mape: 2.6987
# Epoch 27/10000
# 157/157 [==============================] - ETA: 0s - loss: 6.5982 - mape: 6.5982
# Epoch 27: val_loss improved from 2.69865 to 2.69086, saving model to model_best_total_mass_mae_sam_color.keras
# 157/157 [==============================] - 53s 339ms/step - loss: 6.5982 - mape: 6.5982 - val_loss: 2.6909 - val_mape: 2.6909
# Epoch 28/10000
# 157/157 [==============================] - ETA: 0s - loss: 6.3933 - mape: 6.3933
# Epoch 28: val_loss did not improve from 2.69086 of epoch 27
# 157/157 [==============================] - 53s 340ms/step - loss: 6.3933 - mape: 6.3933 - val_loss: 2.7068 - val_mape: 2.7068
# Epoch 29/10000
# 157/157 [==============================] - ETA: 0s - loss: 6.4344 - mape: 6.4344
# Epoch 29: val_loss did not improve from 2.69086 of epoch 27
# 157/157 [==============================] - 53s 341ms/step - loss: 6.4344 - mape: 6.4344 - val_loss: 3.0030 - val_mape: 3.0030
# Epoch 30/10000
# 157/157 [==============================] - ETA: 0s - loss: 6.2485 - mape: 6.2485
# Epoch 30: val_loss improved from 2.69086 to 2.56559, saving model to model_best_total_mass_mae_sam_color.keras
# 157/157 [==============================] - 53s 340ms/step - loss: 6.2485 - mape: 6.2485 - val_loss: 2.5656 - val_mape: 2.5656
# Epoch 31/10000
# 157/157 [==============================] - ETA: 0s - loss: 6.2803 - mape: 6.2803
# Epoch 31: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 54s 341ms/step - loss: 6.2803 - mape: 6.2803 - val_loss: 3.1849 - val_mape: 3.1849
# Epoch 32/10000
# 157/157 [==============================] - ETA: 0s - loss: 6.1004 - mape: 6.1004
# Epoch 32: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 54s 344ms/step - loss: 6.1004 - mape: 6.1004 - val_loss: 5.2854 - val_mape: 5.2854
# Epoch 33/10000
# 157/157 [==============================] - ETA: 0s - loss: 5.9699 - mape: 5.9699
# Epoch 33: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 338ms/step - loss: 5.9699 - mape: 5.9699 - val_loss: 3.5480 - val_mape: 3.5480
# Epoch 34/10000
# 157/157 [==============================] - ETA: 0s - loss: 6.0264 - mape: 6.0264
# Epoch 34: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 54s 342ms/step - loss: 6.0264 - mape: 6.0264 - val_loss: 2.6297 - val_mape: 2.6297
# Epoch 35/10000
# 157/157 [==============================] - ETA: 0s - loss: 5.8542 - mape: 5.8542
# Epoch 35: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 338ms/step - loss: 5.8542 - mape: 5.8542 - val_loss: 2.6091 - val_mape: 2.6091
# Epoch 36/10000
# 157/157 [==============================] - ETA: 0s - loss: 5.7793 - mape: 5.7793
# Epoch 36: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 54s 342ms/step - loss: 5.7793 - mape: 5.7793 - val_loss: 2.9637 - val_mape: 2.9637
# Epoch 37/10000
# 157/157 [==============================] - ETA: 0s - loss: 5.7295 - mape: 5.7295
# Epoch 37: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 336ms/step - loss: 5.7295 - mape: 5.7295 - val_loss: 3.4191 - val_mape: 3.4191
# Epoch 38/10000
# 157/157 [==============================] - ETA: 0s - loss: 5.5998 - mape: 5.5998
# Epoch 38: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 338ms/step - loss: 5.5998 - mape: 5.5998 - val_loss: 3.0880 - val_mape: 3.0880
# Epoch 39/10000
# 157/157 [==============================] - ETA: 0s - loss: 5.5971 - mape: 5.5971
# Epoch 39: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 340ms/step - loss: 5.5971 - mape: 5.5971 - val_loss: 2.6658 - val_mape: 2.6658
# Epoch 40/10000
# 157/157 [==============================] - ETA: 0s - loss: 5.5564 - mape: 5.5564
# Epoch 40: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 338ms/step - loss: 5.5564 - mape: 5.5564 - val_loss: 4.2823 - val_mape: 4.2823
# Epoch 41/10000
# 157/157 [==============================] - ETA: 0s - loss: 5.4084 - mape: 5.4084
# Epoch 41: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 337ms/step - loss: 5.4084 - mape: 5.4084 - val_loss: 2.5774 - val_mape: 2.5774
# Epoch 42/10000
# 157/157 [==============================] - ETA: 0s - loss: 5.4198 - mape: 5.4198
# Epoch 42: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 340ms/step - loss: 5.4198 - mape: 5.4198 - val_loss: 2.7876 - val_mape: 2.7876
# Epoch 43/10000
# 157/157 [==============================] - ETA: 0s - loss: 5.2324 - mape: 5.2324
# Epoch 43: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 340ms/step - loss: 5.2324 - mape: 5.2324 - val_loss: 2.9141 - val_mape: 2.9141
# Epoch 44/10000
# 157/157 [==============================] - ETA: 0s - loss: 5.2312 - mape: 5.2312
# Epoch 44: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 340ms/step - loss: 5.2312 - mape: 5.2312 - val_loss: 3.1563 - val_mape: 3.1563
# Epoch 45/10000
# 157/157 [==============================] - ETA: 0s - loss: 5.1589 - mape: 5.1589
# Epoch 45: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 337ms/step - loss: 5.1589 - mape: 5.1589 - val_loss: 3.6958 - val_mape: 3.6958
# Epoch 46/10000
# 157/157 [==============================] - ETA: 0s - loss: 5.0039 - mape: 5.0039
# Epoch 46: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 54s 341ms/step - loss: 5.0039 - mape: 5.0039 - val_loss: 3.7829 - val_mape: 3.7829
# Epoch 47/10000
# 157/157 [==============================] - ETA: 0s - loss: 5.0440 - mape: 5.0440
# Epoch 47: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 339ms/step - loss: 5.0440 - mape: 5.0440 - val_loss: 2.7986 - val_mape: 2.7986
# Epoch 48/10000
# 157/157 [==============================] - ETA: 0s - loss: 4.8674 - mape: 4.8674
# Epoch 48: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 339ms/step - loss: 4.8674 - mape: 4.8674 - val_loss: 5.7526 - val_mape: 5.7526
# Epoch 49/10000
# 157/157 [==============================] - ETA: 0s - loss: 4.7758 - mape: 4.7758
# Epoch 49: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 336ms/step - loss: 4.7758 - mape: 4.7758 - val_loss: 2.9898 - val_mape: 2.9898
# Epoch 50/10000
# 157/157 [==============================] - ETA: 0s - loss: 4.7104 - mape: 4.7104
# Epoch 50: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 338ms/step - loss: 4.7104 - mape: 4.7104 - val_loss: 2.7205 - val_mape: 2.7205
# Epoch 51/10000
# 157/157 [==============================] - ETA: 0s - loss: 4.5791 - mape: 4.5791
# Epoch 51: val_loss did not improve from 2.56559 of epoch 30
#
# Evaluating on test set at epoch 50
# Mensagem enviada com sucesso!
# 29/29 [==============================] - 2s 58ms/step
# Mensagem enviada com sucesso!
# Mensagem enviada com sucesso!
# Mensagem enviada com sucesso!
# 157/157 [==============================] - 59s 374ms/step - loss: 4.5791 - mape: 4.5791 - val_loss: 2.9234 - val_mape: 2.9234
# Epoch 52/10000
# 157/157 [==============================] - ETA: 0s - loss: 4.5407 - mape: 4.5407
# Epoch 52: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 54s 342ms/step - loss: 4.5407 - mape: 4.5407 - val_loss: 4.2296 - val_mape: 4.2296
# Epoch 53/10000
# 157/157 [==============================] - ETA: 0s - loss: 4.4029 - mape: 4.4029
# Epoch 53: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 336ms/step - loss: 4.4029 - mape: 4.4029 - val_loss: 2.9195 - val_mape: 2.9195
# Epoch 54/10000
# 157/157 [==============================] - ETA: 0s - loss: 4.3554 - mape: 4.3554
# Epoch 54: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 341ms/step - loss: 4.3554 - mape: 4.3554 - val_loss: 3.6235 - val_mape: 3.6235
# Epoch 55/10000
# 157/157 [==============================] - ETA: 0s - loss: 4.1883 - mape: 4.1883
# Epoch 55: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 54s 343ms/step - loss: 4.1883 - mape: 4.1883 - val_loss: 4.9983 - val_mape: 4.9983
# Epoch 56/10000
# 157/157 [==============================] - ETA: 0s - loss: 4.2256 - mape: 4.2256
# Epoch 56: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 340ms/step - loss: 4.2256 - mape: 4.2256 - val_loss: 2.6915 - val_mape: 2.6915
# Epoch 57/10000
# 157/157 [==============================] - ETA: 0s - loss: 4.0729 - mape: 4.0729
# Epoch 57: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 341ms/step - loss: 4.0729 - mape: 4.0729 - val_loss: 2.8347 - val_mape: 2.8347
# Epoch 58/10000
# 157/157 [==============================] - ETA: 0s - loss: 3.9659 - mape: 3.9659
# Epoch 58: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 54s 342ms/step - loss: 3.9659 - mape: 3.9659 - val_loss: 4.5990 - val_mape: 4.5990
# Epoch 59/10000
# 157/157 [==============================] - ETA: 0s - loss: 3.8906 - mape: 3.8906
# Epoch 59: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 340ms/step - loss: 3.8906 - mape: 3.8906 - val_loss: 4.0621 - val_mape: 4.0621
# Epoch 60/10000
# 157/157 [==============================] - ETA: 0s - loss: 3.8493 - mape: 3.8493
# Epoch 60: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 338ms/step - loss: 3.8493 - mape: 3.8493 - val_loss: 2.9787 - val_mape: 2.9787
# Epoch 61/10000
# 157/157 [==============================] - ETA: 0s - loss: 3.7357 - mape: 3.7357
# Epoch 61: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 338ms/step - loss: 3.7357 - mape: 3.7357 - val_loss: 3.1703 - val_mape: 3.1703
# Epoch 62/10000
# 157/157 [==============================] - ETA: 0s - loss: 3.6394 - mape: 3.6394
# Epoch 62: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 340ms/step - loss: 3.6394 - mape: 3.6394 - val_loss: 2.9572 - val_mape: 2.9572
# Epoch 63/10000
# 157/157 [==============================] - ETA: 0s - loss: 3.6721 - mape: 3.6721
# Epoch 63: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 341ms/step - loss: 3.6721 - mape: 3.6721 - val_loss: 3.1971 - val_mape: 3.1971
# Epoch 64/10000
# 157/157 [==============================] - ETA: 0s - loss: 3.5442 - mape: 3.5442
# Epoch 64: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 340ms/step - loss: 3.5442 - mape: 3.5442 - val_loss: 2.8587 - val_mape: 2.8587
# Epoch 65/10000
# 157/157 [==============================] - ETA: 0s - loss: 3.4737 - mape: 3.4737
# Epoch 65: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 338ms/step - loss: 3.4737 - mape: 3.4737 - val_loss: 2.9407 - val_mape: 2.9407
# Epoch 66/10000
# 157/157 [==============================] - ETA: 0s - loss: 3.4996 - mape: 3.4996
# Epoch 66: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 338ms/step - loss: 3.4996 - mape: 3.4996 - val_loss: 2.8773 - val_mape: 2.8773
# Epoch 67/10000
# 157/157 [==============================] - ETA: 0s - loss: 3.3289 - mape: 3.3289
# Epoch 67: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 340ms/step - loss: 3.3289 - mape: 3.3289 - val_loss: 4.3046 - val_mape: 4.3046
# Epoch 68/10000
# 157/157 [==============================] - ETA: 0s - loss: 3.3378 - mape: 3.3378
# Epoch 68: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 340ms/step - loss: 3.3378 - mape: 3.3378 - val_loss: 4.5637 - val_mape: 4.5637
# Epoch 69/10000
# 157/157 [==============================] - ETA: 0s - loss: 3.3104 - mape: 3.3104
# Epoch 69: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 339ms/step - loss: 3.3104 - mape: 3.3104 - val_loss: 3.9418 - val_mape: 3.9418
# Epoch 70/10000
# 157/157 [==============================] - ETA: 0s - loss: 3.1390 - mape: 3.1390
# Epoch 70: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 54s 342ms/step - loss: 3.1390 - mape: 3.1390 - val_loss: 3.0297 - val_mape: 3.0297
# Epoch 71/10000
# 157/157 [==============================] - ETA: 0s - loss: 3.1821 - mape: 3.1821
# Epoch 71: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 54s 341ms/step - loss: 3.1821 - mape: 3.1821 - val_loss: 2.9932 - val_mape: 2.9932
# Epoch 72/10000
# 157/157 [==============================] - ETA: 0s - loss: 3.1787 - mape: 3.1787
# Epoch 72: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 340ms/step - loss: 3.1787 - mape: 3.1787 - val_loss: 2.6822 - val_mape: 2.6822
# Epoch 73/10000
# 157/157 [==============================] - ETA: 0s - loss: 3.1083 - mape: 3.1083
# Epoch 73: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 338ms/step - loss: 3.1083 - mape: 3.1083 - val_loss: 4.2432 - val_mape: 4.2432
# Epoch 74/10000
# 157/157 [==============================] - ETA: 0s - loss: 3.0712 - mape: 3.0712
# Epoch 74: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 341ms/step - loss: 3.0712 - mape: 3.0712 - val_loss: 3.0594 - val_mape: 3.0594
# Epoch 75/10000
# 157/157 [==============================] - ETA: 0s - loss: 3.0424 - mape: 3.0424
# Epoch 75: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 338ms/step - loss: 3.0424 - mape: 3.0424 - val_loss: 3.7949 - val_mape: 3.7949
# Epoch 76/10000
# 157/157 [==============================] - ETA: 0s - loss: 3.0017 - mape: 3.0017
# Epoch 76: val_loss did not improve from 2.56559 of epoch 30
#
# Evaluating on test set at epoch 75
# Mensagem enviada com sucesso!
# 29/29 [==============================] - 2s 56ms/step
# Mensagem enviada com sucesso!
# Mensagem enviada com sucesso!
# Mensagem enviada com sucesso!
# 157/157 [==============================] - 58s 373ms/step - loss: 3.0017 - mape: 3.0017 - val_loss: 4.8692 - val_mape: 4.8692
# Epoch 77/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.9901 - mape: 2.9901
# Epoch 77: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 338ms/step - loss: 2.9901 - mape: 2.9901 - val_loss: 2.9026 - val_mape: 2.9026
# Epoch 78/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.9257 - mape: 2.9257
# Epoch 78: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 338ms/step - loss: 2.9257 - mape: 2.9257 - val_loss: 3.9760 - val_mape: 3.9760
# Epoch 79/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.9304 - mape: 2.9304
# Epoch 79: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 339ms/step - loss: 2.9304 - mape: 2.9304 - val_loss: 2.6153 - val_mape: 2.6153
# Epoch 80/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.8559 - mape: 2.8559
# Epoch 80: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 339ms/step - loss: 2.8559 - mape: 2.8559 - val_loss: 2.6873 - val_mape: 2.6873
# Epoch 81/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.8428 - mape: 2.8428
# Epoch 81: val_loss did not improve from 2.56559 of epoch 30
# 157/157 [==============================] - 53s 336ms/step - loss: 2.8428 - mape: 2.8428 - val_loss: 3.4188 - val_mape: 3.4188
# Epoch 82/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.8169 - mape: 2.8169
# Epoch 82: val_loss improved from 2.56559 to 2.45558, saving model to model_best_total_mass_mae_sam_color.keras
# 157/157 [==============================] - 53s 336ms/step - loss: 2.8169 - mape: 2.8169 - val_loss: 2.4556 - val_mape: 2.4556
# Epoch 83/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.8135 - mape: 2.8135
# Epoch 83: val_loss did not improve from 2.45558 of epoch 82
# 157/157 [==============================] - 53s 340ms/step - loss: 2.8135 - mape: 2.8135 - val_loss: 4.6505 - val_mape: 4.6505
# Epoch 84/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.7140 - mape: 2.7140
# Epoch 84: val_loss did not improve from 2.45558 of epoch 82
# 157/157 [==============================] - 53s 337ms/step - loss: 2.7140 - mape: 2.7140 - val_loss: 3.3093 - val_mape: 3.3093
# Epoch 85/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.7809 - mape: 2.7809
# Epoch 85: val_loss did not improve from 2.45558 of epoch 82
# 157/157 [==============================] - 53s 337ms/step - loss: 2.7809 - mape: 2.7809 - val_loss: 3.2247 - val_mape: 3.2247
# Epoch 86/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.7178 - mape: 2.7178
# Epoch 86: val_loss did not improve from 2.45558 of epoch 82
# 157/157 [==============================] - 54s 342ms/step - loss: 2.7178 - mape: 2.7178 - val_loss: 2.4756 - val_mape: 2.4756
# Epoch 87/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.7621 - mape: 2.7621
# Epoch 87: val_loss did not improve from 2.45558 of epoch 82
# 157/157 [==============================] - 53s 338ms/step - loss: 2.7621 - mape: 2.7621 - val_loss: 3.7706 - val_mape: 3.7706
# Epoch 88/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.6422 - mape: 2.6422
# Epoch 88: val_loss did not improve from 2.45558 of epoch 82
# 157/157 [==============================] - 53s 339ms/step - loss: 2.6422 - mape: 2.6422 - val_loss: 3.0030 - val_mape: 3.0030
# Epoch 89/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.6473 - mape: 2.6473
# Epoch 89: val_loss did not improve from 2.45558 of epoch 82
# 157/157 [==============================] - 53s 338ms/step - loss: 2.6473 - mape: 2.6473 - val_loss: 4.0690 - val_mape: 4.0690
# Epoch 90/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.6224 - mape: 2.6224
# Epoch 90: val_loss did not improve from 2.45558 of epoch 82
# 157/157 [==============================] - 54s 343ms/step - loss: 2.6224 - mape: 2.6224 - val_loss: 2.5119 - val_mape: 2.5119
# Epoch 91/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.5576 - mape: 2.5576
# Epoch 91: val_loss did not improve from 2.45558 of epoch 82
# 157/157 [==============================] - 53s 340ms/step - loss: 2.5576 - mape: 2.5576 - val_loss: 3.0437 - val_mape: 3.0437
# Epoch 92/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.5732 - mape: 2.5732
# Epoch 92: val_loss did not improve from 2.45558 of epoch 82
# 157/157 [==============================] - 53s 338ms/step - loss: 2.5732 - mape: 2.5732 - val_loss: 2.6539 - val_mape: 2.6539
# Epoch 93/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.5932 - mape: 2.5932
# Epoch 93: val_loss did not improve from 2.45558 of epoch 82
# 157/157 [==============================] - 53s 339ms/step - loss: 2.5932 - mape: 2.5932 - val_loss: 3.0646 - val_mape: 3.0646
# Epoch 94/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.5037 - mape: 2.5037
# Epoch 94: val_loss did not improve from 2.45558 of epoch 82
# 157/157 [==============================] - 53s 341ms/step - loss: 2.5037 - mape: 2.5037 - val_loss: 2.6829 - val_mape: 2.6829
# Epoch 95/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.5191 - mape: 2.5191
# Epoch 95: val_loss did not improve from 2.45558 of epoch 82
# 157/157 [==============================] - 53s 340ms/step - loss: 2.5191 - mape: 2.5191 - val_loss: 2.6637 - val_mape: 2.6637
# Epoch 96/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.5803 - mape: 2.5803
# Epoch 96: val_loss did not improve from 2.45558 of epoch 82
# 157/157 [==============================] - 53s 340ms/step - loss: 2.5803 - mape: 2.5803 - val_loss: 2.7171 - val_mape: 2.7171
# Epoch 97/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.5335 - mape: 2.5335
# Epoch 97: val_loss did not improve from 2.45558 of epoch 82
# 157/157 [==============================] - 53s 337ms/step - loss: 2.5335 - mape: 2.5335 - val_loss: 2.7564 - val_mape: 2.7564
# Epoch 98/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.4799 - mape: 2.4799
# Epoch 98: val_loss did not improve from 2.45558 of epoch 82
# 157/157 [==============================] - 53s 340ms/step - loss: 2.4799 - mape: 2.4799 - val_loss: 2.7180 - val_mape: 2.7180
# Epoch 99/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.4867 - mape: 2.4867
# Epoch 99: val_loss did not improve from 2.45558 of epoch 82
# 157/157 [==============================] - 54s 346ms/step - loss: 2.4867 - mape: 2.4867 - val_loss: 3.9867 - val_mape: 3.9867
# Epoch 100/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.4308 - mape: 2.4308
# Epoch 100: val_loss improved from 2.45558 to 2.31283, saving model to model_best_total_mass_mae_sam_color.keras
# 157/157 [==============================] - 53s 338ms/step - loss: 2.4308 - mape: 2.4308 - val_loss: 2.3128 - val_mape: 2.3128
# Epoch 101/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.5423 - mape: 2.5423
# Epoch 101: val_loss improved from 2.31283 to 2.15305, saving model to model_best_total_mass_mae_sam_color.keras
#
# Evaluating on test set at epoch 100
# Mensagem enviada com sucesso!
# 29/29 [==============================] - 2s 60ms/step
# Mensagem enviada com sucesso!
# Mensagem enviada com sucesso!
# Mensagem enviada com sucesso!
# 157/157 [==============================] - 59s 374ms/step - loss: 2.5423 - mape: 2.5423 - val_loss: 2.1530 - val_mape: 2.1530
# Epoch 102/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.3904 - mape: 2.3904
# Epoch 102: val_loss did not improve from 2.15305 of epoch 101
# 157/157 [==============================] - 54s 342ms/step - loss: 2.3904 - mape: 2.3904 - val_loss: 2.7929 - val_mape: 2.7929
# Epoch 103/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.4092 - mape: 2.4092
# Epoch 103: val_loss did not improve from 2.15305 of epoch 101
# 157/157 [==============================] - 54s 342ms/step - loss: 2.4092 - mape: 2.4092 - val_loss: 2.3692 - val_mape: 2.3692
# Epoch 104/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.5356 - mape: 2.5356
# Epoch 104: val_loss did not improve from 2.15305 of epoch 101
# 157/157 [==============================] - 53s 338ms/step - loss: 2.5356 - mape: 2.5356 - val_loss: 2.7371 - val_mape: 2.7371
# Epoch 105/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.4516 - mape: 2.4516
# Epoch 105: val_loss did not improve from 2.15305 of epoch 101
# 157/157 [==============================] - 53s 336ms/step - loss: 2.4516 - mape: 2.4516 - val_loss: 2.4889 - val_mape: 2.4889
# Epoch 106/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.4324 - mape: 2.4324
# Epoch 106: val_loss did not improve from 2.15305 of epoch 101
# 157/157 [==============================] - 53s 341ms/step - loss: 2.4324 - mape: 2.4324 - val_loss: 3.5514 - val_mape: 3.5514
# Epoch 107/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.3906 - mape: 2.3906
# Epoch 107: val_loss did not improve from 2.15305 of epoch 101
# 157/157 [==============================] - 53s 338ms/step - loss: 2.3906 - mape: 2.3906 - val_loss: 2.9810 - val_mape: 2.9810
# Epoch 108/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.4648 - mape: 2.4648
# Epoch 108: val_loss did not improve from 2.15305 of epoch 101
# 157/157 [==============================] - 53s 341ms/step - loss: 2.4648 - mape: 2.4648 - val_loss: 2.8565 - val_mape: 2.8565
# Epoch 109/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.3922 - mape: 2.3922
# Epoch 109: val_loss did not improve from 2.15305 of epoch 101
# 157/157 [==============================] - 53s 338ms/step - loss: 2.3922 - mape: 2.3922 - val_loss: 4.0621 - val_mape: 4.0621
# Epoch 110/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.3776 - mape: 2.3776
# Epoch 110: val_loss did not improve from 2.15305 of epoch 101
# 157/157 [==============================] - 53s 340ms/step - loss: 2.3776 - mape: 2.3776 - val_loss: 2.6986 - val_mape: 2.6986
# Epoch 111/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.3735 - mape: 2.3735
# Epoch 111: val_loss did not improve from 2.15305 of epoch 101
# 157/157 [==============================] - 53s 340ms/step - loss: 2.3735 - mape: 2.3735 - val_loss: 3.2454 - val_mape: 3.2454
# Epoch 112/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.4067 - mape: 2.4067
# Epoch 112: val_loss did not improve from 2.15305 of epoch 101
# 157/157 [==============================] - 53s 339ms/step - loss: 2.4067 - mape: 2.4067 - val_loss: 2.9605 - val_mape: 2.9605
# Epoch 113/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.2546 - mape: 2.2546
# Epoch 113: val_loss did not improve from 2.15305 of epoch 101
# 157/157 [==============================] - 53s 339ms/step - loss: 2.2546 - mape: 2.2546 - val_loss: 3.0277 - val_mape: 3.0277
# Epoch 114/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.4240 - mape: 2.4240
# Epoch 114: val_loss did not improve from 2.15305 of epoch 101
# 157/157 [==============================] - 54s 341ms/step - loss: 2.4240 - mape: 2.4240 - val_loss: 2.6651 - val_mape: 2.6651
# Epoch 115/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.3449 - mape: 2.3449
# Epoch 115: val_loss did not improve from 2.15305 of epoch 101
# 157/157 [==============================] - 53s 339ms/step - loss: 2.3449 - mape: 2.3449 - val_loss: 4.3281 - val_mape: 4.3281
# Epoch 116/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.3008 - mape: 2.3008
# Epoch 116: val_loss did not improve from 2.15305 of epoch 101
# 157/157 [==============================] - 53s 340ms/step - loss: 2.3008 - mape: 2.3008 - val_loss: 2.9295 - val_mape: 2.9295
# Epoch 117/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.3167 - mape: 2.3167
# Epoch 117: val_loss improved from 2.15305 to 2.12356, saving model to model_best_total_mass_mae_sam_color.keras
# 157/157 [==============================] - 54s 342ms/step - loss: 2.3167 - mape: 2.3167 - val_loss: 2.1236 - val_mape: 2.1236
# Epoch 118/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.3508 - mape: 2.3508
# Epoch 118: val_loss did not improve from 2.12356 of epoch 117
# 157/157 [==============================] - 53s 340ms/step - loss: 2.3508 - mape: 2.3508 - val_loss: 2.3133 - val_mape: 2.3133
# Epoch 119/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.3162 - mape: 2.3162
# Epoch 119: val_loss did not improve from 2.12356 of epoch 117
# 157/157 [==============================] - 53s 339ms/step - loss: 2.3162 - mape: 2.3162 - val_loss: 2.7593 - val_mape: 2.7593
# Epoch 120/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.2973 - mape: 2.2973
# Epoch 120: val_loss improved from 2.12356 to 2.00295, saving model to model_best_total_mass_mae_sam_color.keras
# 157/157 [==============================] - 54s 342ms/step - loss: 2.2973 - mape: 2.2973 - val_loss: 2.0029 - val_mape: 2.0029
# Epoch 121/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.2770 - mape: 2.2770
# Epoch 121: val_loss did not improve from 2.00295 of epoch 120
# 157/157 [==============================] - 53s 338ms/step - loss: 2.2770 - mape: 2.2770 - val_loss: 2.9220 - val_mape: 2.9220
# Epoch 122/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.3074 - mape: 2.3074
# Epoch 122: val_loss did not improve from 2.00295 of epoch 120
# 157/157 [==============================] - 53s 339ms/step - loss: 2.3074 - mape: 2.3074 - val_loss: 2.3057 - val_mape: 2.3057
# Epoch 123/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.3019 - mape: 2.3019
# Epoch 123: val_loss did not improve from 2.00295 of epoch 120
# 157/157 [==============================] - 54s 341ms/step - loss: 2.3019 - mape: 2.3019 - val_loss: 2.2386 - val_mape: 2.2386
# Epoch 124/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.2828 - mape: 2.2828
# Epoch 124: val_loss did not improve from 2.00295 of epoch 120
# 157/157 [==============================] - 54s 341ms/step - loss: 2.2828 - mape: 2.2828 - val_loss: 2.8228 - val_mape: 2.8228
# Epoch 125/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.3068 - mape: 2.3068
# Epoch 125: val_loss did not improve from 2.00295 of epoch 120
# 157/157 [==============================] - 53s 339ms/step - loss: 2.3068 - mape: 2.3068 - val_loss: 2.6348 - val_mape: 2.6348
# Epoch 126/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.2817 - mape: 2.2817
# Epoch 126: val_loss did not improve from 2.00295 of epoch 120
#
# Evaluating on test set at epoch 125
# Mensagem enviada com sucesso!
# 29/29 [==============================] - 2s 58ms/step
# Mensagem enviada com sucesso!
# Mensagem enviada com sucesso!
# Mensagem enviada com sucesso!
# 157/157 [==============================] - 59s 375ms/step - loss: 2.2817 - mape: 2.2817 - val_loss: 2.4262 - val_mape: 2.4262
# Epoch 127/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.2802 - mape: 2.2802
# Epoch 127: val_loss did not improve from 2.00295 of epoch 120
# 157/157 [==============================] - 54s 341ms/step - loss: 2.2802 - mape: 2.2802 - val_loss: 3.6692 - val_mape: 3.6692
# Epoch 128/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.2794 - mape: 2.2794
# Epoch 128: val_loss did not improve from 2.00295 of epoch 120
# 157/157 [==============================] - 53s 340ms/step - loss: 2.2794 - mape: 2.2794 - val_loss: 4.4879 - val_mape: 4.4879
# Epoch 129/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.2986 - mape: 2.2986
# Epoch 129: val_loss did not improve from 2.00295 of epoch 120
# 157/157 [==============================] - 53s 339ms/step - loss: 2.2986 - mape: 2.2986 - val_loss: 3.0524 - val_mape: 3.0524
# Epoch 130/10000
# 157/157 [==============================] - ETA: 0s - loss: 2.2083 - mape: 2.2083
# Epoch 130: val_loss did not improve from 2.00295 of epoch 120
# ...
# Epoch 241/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8463 - mape: 1.8463
# Epoch 241: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 340ms/step - loss: 1.8463 - mape: 1.8463 - val_loss: 2.4994 - val_mape: 2.4994
# Epoch 242/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8220 - mape: 1.8220
# Epoch 242: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 339ms/step - loss: 1.8220 - mape: 1.8220 - val_loss: 2.5051 - val_mape: 2.5051
# Epoch 243/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.9115 - mape: 1.9115
# Epoch 243: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 54s 343ms/step - loss: 1.9115 - mape: 1.9115 - val_loss: 3.1902 - val_mape: 3.1902
# Epoch 244/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8386 - mape: 1.8386
# Epoch 244: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 54s 341ms/step - loss: 1.8386 - mape: 1.8386 - val_loss: 3.4253 - val_mape: 3.4253
# Epoch 245/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8505 - mape: 1.8505
# Epoch 245: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 339ms/step - loss: 1.8505 - mape: 1.8505 - val_loss: 1.8934 - val_mape: 1.8934
# Epoch 246/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8230 - mape: 1.8230
# Epoch 246: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 54s 342ms/step - loss: 1.8230 - mape: 1.8230 - val_loss: 2.1685 - val_mape: 2.1685
# Epoch 247/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8522 - mape: 1.8522
# Epoch 247: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 54s 342ms/step - loss: 1.8522 - mape: 1.8522 - val_loss: 2.3948 - val_mape: 2.3948
# Epoch 248/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8685 - mape: 1.8685
# Epoch 248: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 338ms/step - loss: 1.8685 - mape: 1.8685 - val_loss: 3.7724 - val_mape: 3.7724
# Epoch 249/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8663 - mape: 1.8663
# Epoch 249: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 339ms/step - loss: 1.8663 - mape: 1.8663 - val_loss: 2.4159 - val_mape: 2.4159
# Epoch 250/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.9032 - mape: 1.9032
# Epoch 250: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 337ms/step - loss: 1.9032 - mape: 1.9032 - val_loss: 2.3016 - val_mape: 2.3016
# Epoch 251/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8950 - mape: 1.8950
# Epoch 251: val_loss did not improve from 1.80567 of epoch 194
#
# Evaluating on test set at epoch 250
# Mensagem enviada com sucesso!
# 29/29 [==============================] - 2s 56ms/step
# Mensagem enviada com sucesso!
# Mensagem enviada com sucesso!
# Mensagem enviada com sucesso!
# 157/157 [==============================] - 59s 376ms/step - loss: 1.8950 - mape: 1.8950 - val_loss: 2.4718 - val_mape: 2.4718
# Epoch 252/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.9124 - mape: 1.9124
# Epoch 252: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 338ms/step - loss: 1.9124 - mape: 1.9124 - val_loss: 2.1568 - val_mape: 2.1568
# Epoch 253/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8575 - mape: 1.8575
# Epoch 253: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 337ms/step - loss: 1.8575 - mape: 1.8575 - val_loss: 2.2493 - val_mape: 2.2493
# Epoch 254/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8156 - mape: 1.8156
# Epoch 254: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 338ms/step - loss: 1.8156 - mape: 1.8156 - val_loss: 2.8613 - val_mape: 2.8613
# Epoch 255/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8117 - mape: 1.8117
# Epoch 255: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 339ms/step - loss: 1.8117 - mape: 1.8117 - val_loss: 4.0602 - val_mape: 4.0602
# Epoch 256/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.7826 - mape: 1.7826
# Epoch 256: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 340ms/step - loss: 1.7826 - mape: 1.7826 - val_loss: 2.7452 - val_mape: 2.7452
# Epoch 257/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.7923 - mape: 1.7923
# Epoch 257: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 340ms/step - loss: 1.7923 - mape: 1.7923 - val_loss: 3.9573 - val_mape: 3.9573
# Epoch 258/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8552 - mape: 1.8552
# Epoch 258: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 339ms/step - loss: 1.8552 - mape: 1.8552 - val_loss: 2.5704 - val_mape: 2.5704
# Epoch 259/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.7634 - mape: 1.7634
# Epoch 259: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 338ms/step - loss: 1.7634 - mape: 1.7634 - val_loss: 2.7183 - val_mape: 2.7183
# Epoch 260/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8047 - mape: 1.8047
# Epoch 260: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 339ms/step - loss: 1.8047 - mape: 1.8047 - val_loss: 3.4963 - val_mape: 3.4963
# Epoch 261/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8149 - mape: 1.8149
# Epoch 261: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 338ms/step - loss: 1.8149 - mape: 1.8149 - val_loss: 2.8353 - val_mape: 2.8353
# Epoch 262/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8277 - mape: 1.8277
# Epoch 262: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 339ms/step - loss: 1.8277 - mape: 1.8277 - val_loss: 2.5774 - val_mape: 2.5774
# Epoch 263/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8151 - mape: 1.8151
# Epoch 263: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 339ms/step - loss: 1.8151 - mape: 1.8151 - val_loss: 2.9303 - val_mape: 2.9303
# Epoch 264/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8589 - mape: 1.8589
# Epoch 264: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 339ms/step - loss: 1.8589 - mape: 1.8589 - val_loss: 3.5808 - val_mape: 3.5808
# Epoch 265/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.7687 - mape: 1.7687
# Epoch 265: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 52s 335ms/step - loss: 1.7687 - mape: 1.7687 - val_loss: 2.5702 - val_mape: 2.5702
# Epoch 266/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8013 - mape: 1.8013
# Epoch 266: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 337ms/step - loss: 1.8013 - mape: 1.8013 - val_loss: 3.4755 - val_mape: 3.4755
# Epoch 267/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8639 - mape: 1.8639
# Epoch 267: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 339ms/step - loss: 1.8639 - mape: 1.8639 - val_loss: 2.6202 - val_mape: 2.6202
# Epoch 268/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8925 - mape: 1.8925
# Epoch 268: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 338ms/step - loss: 1.8925 - mape: 1.8925 - val_loss: 4.5316 - val_mape: 4.5316
# Epoch 269/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8829 - mape: 1.8829
# Epoch 269: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 340ms/step - loss: 1.8829 - mape: 1.8829 - val_loss: 2.6933 - val_mape: 2.6933
# Epoch 270/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8535 - mape: 1.8535
# Epoch 270: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 338ms/step - loss: 1.8535 - mape: 1.8535 - val_loss: 2.0957 - val_mape: 2.0957
# Epoch 271/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8409 - mape: 1.8409
# Epoch 271: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 337ms/step - loss: 1.8409 - mape: 1.8409 - val_loss: 3.2035 - val_mape: 3.2035
# Epoch 272/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8193 - mape: 1.8193
# Epoch 272: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 338ms/step - loss: 1.8193 - mape: 1.8193 - val_loss: 3.7320 - val_mape: 3.7320
# Epoch 273/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8820 - mape: 1.8820
# Epoch 273: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 337ms/step - loss: 1.8820 - mape: 1.8820 - val_loss: 2.9519 - val_mape: 2.9519
# Epoch 274/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8501 - mape: 1.8501
# Epoch 274: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 340ms/step - loss: 1.8501 - mape: 1.8501 - val_loss: 2.3344 - val_mape: 2.3344
# Epoch 275/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8273 - mape: 1.8273
# Epoch 275: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 337ms/step - loss: 1.8273 - mape: 1.8273 - val_loss: 1.9333 - val_mape: 1.9333
# Epoch 276/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8955 - mape: 1.8955
# Epoch 276: val_loss did not improve from 1.80567 of epoch 194
#
# Evaluating on test set at epoch 275
# Mensagem enviada com sucesso!
# 29/29 [==============================] - 2s 57ms/step
# Mensagem enviada com sucesso!
# Mensagem enviada com sucesso!
# Mensagem enviada com sucesso!
# 157/157 [==============================] - 59s 373ms/step - loss: 1.8955 - mape: 1.8955 - val_loss: 2.4796 - val_mape: 2.4796
# Epoch 277/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8454 - mape: 1.8454
# Epoch 277: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 335ms/step - loss: 1.8454 - mape: 1.8454 - val_loss: 2.9088 - val_mape: 2.9088
# Epoch 278/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8353 - mape: 1.8353
# Epoch 278: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 340ms/step - loss: 1.8353 - mape: 1.8353 - val_loss: 4.4611 - val_mape: 4.4611
# Epoch 279/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.7518 - mape: 1.7518
# Epoch 279: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 339ms/step - loss: 1.7518 - mape: 1.7518 - val_loss: 1.9355 - val_mape: 1.9355
# Epoch 280/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8175 - mape: 1.8175
# Epoch 280: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 340ms/step - loss: 1.8175 - mape: 1.8175 - val_loss: 4.2324 - val_mape: 4.2324
# Epoch 281/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.7843 - mape: 1.7843
# Epoch 281: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 338ms/step - loss: 1.7843 - mape: 1.7843 - val_loss: 2.2433 - val_mape: 2.2433
# Epoch 282/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.7658 - mape: 1.7658
# Epoch 282: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 338ms/step - loss: 1.7658 - mape: 1.7658 - val_loss: 2.9727 - val_mape: 2.9727
# Epoch 283/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8275 - mape: 1.8275
# Epoch 283: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 338ms/step - loss: 1.8275 - mape: 1.8275 - val_loss: 3.2445 - val_mape: 3.2445
# Epoch 284/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8591 - mape: 1.8591
# Epoch 284: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 339ms/step - loss: 1.8591 - mape: 1.8591 - val_loss: 3.0310 - val_mape: 3.0310
# Epoch 285/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.7742 - mape: 1.7742
# Epoch 285: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 337ms/step - loss: 1.7742 - mape: 1.7742 - val_loss: 2.3043 - val_mape: 2.3043
# Epoch 286/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8167 - mape: 1.8167
# Epoch 286: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 338ms/step - loss: 1.8167 - mape: 1.8167 - val_loss: 3.8182 - val_mape: 3.8182
# Epoch 287/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.7689 - mape: 1.7689
# Epoch 287: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 337ms/step - loss: 1.7689 - mape: 1.7689 - val_loss: 2.4272 - val_mape: 2.4272
# Epoch 288/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.7818 - mape: 1.7818
# Epoch 288: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 339ms/step - loss: 1.7818 - mape: 1.7818 - val_loss: 2.2513 - val_mape: 2.2513
# Epoch 289/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.7213 - mape: 1.7213
# Epoch 289: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 336ms/step - loss: 1.7213 - mape: 1.7213 - val_loss: 3.0458 - val_mape: 3.0458
# Epoch 290/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8058 - mape: 1.8058
# Epoch 290: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 339ms/step - loss: 1.8058 - mape: 1.8058 - val_loss: 2.0649 - val_mape: 2.0649
# Epoch 291/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8138 - mape: 1.8138
# Epoch 291: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 340ms/step - loss: 1.8138 - mape: 1.8138 - val_loss: 2.5350 - val_mape: 2.5350
# Epoch 292/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.7844 - mape: 1.7844
# Epoch 292: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 338ms/step - loss: 1.7844 - mape: 1.7844 - val_loss: 2.9329 - val_mape: 2.9329
# Epoch 293/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8484 - mape: 1.8484
# Epoch 293: val_loss did not improve from 1.80567 of epoch 194
# 157/157 [==============================] - 53s 340ms/step - loss: 1.8484 - mape: 1.8484 - val_loss: 2.4099 - val_mape: 2.4099
# Epoch 294/10000
# 157/157 [==============================] - ETA: 0s - loss: 1.8485 - mape: 1.8485
# Epoch 294: val_loss did not improve from 1.80567 of epoch 194
# Restoring model weights from the end of the best epoch: 194.
# 157/157 [==============================] - 53s 338ms/step - loss: 1.8485 - mape: 1.8485 - val_loss: 3.3442 - val_mape: 3.3442
# Epoch 294: early stopping

# %%
import datetime
send_telegram_message(datetime.datetime.now().strftime("%d/%m/%Y %H:%M:%S"))
# Out:
# Mensagem enviada com sucesso!

# %%
# #load the best model
# from keras import models
# # model = models.load_model(model_checkpoint_path)
# model = models.load_model('model_teste.keras')

# %%
import matplotlib.pyplot as plt
if history:
    # Plotar a perda de treinamento e validação
    plt.plot(history.history['loss'], label='Perda de Treinamento')
    plt.plot(history.history['val_loss'], label='Perda de Validação')
    plt.title('Gráfico de Aprendizado')
    plt.ylabel('Perda')
    plt.xlabel('Época')
    plt.legend()
    #save the figure as a PNG file
    plt.savefig('training_loss.png')
    plt.show()

# %%
if history:
    send_telegram_image('training_loss.png')
    history_df = pd.DataFrame(history.history)

    # Save the history DataFrame to a CSV file
    history_df.to_csv(f'training_history_mass_sam_{"grayscale" if grayscale else "color"}.csv', index=False)
    
    send_telegram_file(history_path)
# Out:
# Imagem enviada com sucesso!
# Arquivo enviado com sucesso!

# %%
#keras load model
from keras import models
model = models.load_model('model_best_total_mass_mae_sam_color.keras')
# Out:
# 2024-11-18 03:58:06.324479: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-18 03:58:06.346508: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-18 03:58:06.346646: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-18 03:58:06.347668: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-18 03:58:06.347782: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-18 03:58:06.347844: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-18 03:58:06.389557: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-18 03:58:06.389671: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-18 03:58:06.389745: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-18 03:58:06.389812: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22110 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
performance = model.evaluate(X_test, Y_test, verbose=0)
print(f"The model's performance is {performance[1]:.4f} MAE on the test set")
#print the mape
# print(f"MAE: {performance[1]:.4f}, MAPE: {performance[1]:.4f}")
# send_telegram_message(f"MAE: {performance[1]:.4f}, MAPE: {performance[1]:.4f}")
# Out:
# 2024-11-18 03:58:14.982835: W external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:225] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.9
# 2024-11-18 03:58:14.983118: W external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:228] Used ptxas at ptxas
# 2024-11-18 03:58:14.983875: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-18 03:58:15.024032: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8902
# 2024-11-18 03:58:15.053414: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-18 03:58:15.053447: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-18 03:58:15.054839: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-18 03:58:15.054862: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-18 03:58:15.054874: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-18 03:58:15.055542: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-18 03:58:15.055556: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-18 03:58:15.055566: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-11-18 03:58:15.093508: W external/local_xla/xla/stream_executor/gpu/redzone_allocator.cc:322] UNIMPLEMENTED: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2024-11-18 03:58:15.876667: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# The model's performance is 2.7567 MAE on the test set

# %%
# Fazer as previsões
Y_pred = model.predict(X_test)

# Inicializar um dicionário para armazenar DataFrames separados para cada coluna de saída
result_dfs = {}

# Iterar sobre cada coluna de saída e preencher os resultados em DataFrames separados
for idx, col_name in enumerate(objective_columns):
    result = {
        "real": Y_test[:, idx],
        "predict": Y_pred[:, idx],
        "difference": abs(Y_pred[:, idx] - Y_test[:, idx])
    }
    # Criar DataFrame para a saída específica
    result_dfs[col_name] = pd.DataFrame(result)

# # Adicionar "Casca Calculada", "Gema Calculada" e "Clara Calculada" aos DataFrames
# result_dfs['Casca Calculada'] = result_dfs['Massa Total Aferido'] - result_dfs['Gema + Clara']
# result_dfs['Gema Calculada'] = result_dfs['Gema + Clara'] - result_dfs['Clara']
# result_dfs['Clara Calculada'] = result_dfs['Gema + Clara'] - result_dfs['Gema']

# result_dfs['Casca Calculada 2'] = result_dfs['Massa Total Aferido'] - result_dfs['Gema'] - result_dfs['Clara']
# result_dfs['Gema Calculada 2'] = result_dfs['Massa Total Aferido'] - result_dfs['Casca'] - result_dfs['Clara']
# result_dfs['Clara Calculada 2'] = result_dfs['Gema + Clara'] - result_dfs['Casca'] - result_dfs['Gema']
# Out:
# 29/29 [==============================] - 1s 37ms/step

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error, r2_score
import pandas as pd

# Criar um dicionário para armazenar as métricas para cada coluna
metrics = {}

# Calcular as métricas para cada objetivo (variável de saída)
for col_name, df in result_dfs.items():
    mae = mean_absolute_error(df['real'], df['predict'])
    mape = mean_absolute_percentage_error(df['real'], df['predict'])
    mse = mean_squared_error(df['real'], df['predict'])
    r2 = r2_score(df['real'], df['predict'])
    
    # Armazenar as métricas no dicionário
    metrics[col_name] = {
        'MAE': mae,
        'MAPE': mape,
        'MSE': mse,
        'R2': r2
    }

# Printar as métricas para cada objetivo
# for col_name, metric_values in metrics.items():
#     print(f"Métricas para {col_name}: mae = {metric_values['MAE']:.2f}, mape = {100 * metric_values['MAPE']:.2f}%, mse = {metric_values['MSE']:.2f}, r2 = {metric_values['R2']:.2f}")
#     # send_telegram_message(f"Métricas para {col_name}: mae = {metric_values['MAE']:.2f}, mape = {100 * metric_values['MAPE']:.2f}%, mse = {metric_values['MSE']:.2f}, r2 = {metric_values['R2']:.2f}")

# Converter o dicionário de métricas em um DataFrame e ordenar alfabeticamente
metrics_df = pd.DataFrame(metrics).T.sort_index()  # Transpor e ordenar pelo índice

# Exibir o DataFrame com as métricas
print("\nResumo das métricas (em ordem alfabética):")
print(metrics_df)

# for col_name, metric_values in metrics.items():
    # print(f"Métricas para {col_name}: mae = {metric_values['MAE']:.2f}, mape = {100 * metric_values['MAPE']:.2f}%, mse = {metric_values['MSE']:.2f}, r2 = {metric_values['R2']:.2f}")
    # send_telegram_message(f"Métricas para {col_name}: mae = {metric_values['MAE']:.2f}, mape = {100 * metric_values['MAPE']:.2f}%, mse = {metric_values['MSE']:.2f}, r2 = {metric_values['R2']:.2f}")
# Out:
# Resumo das métricas (em ordem alfabética):
#                           MAE      MAPE       MSE        R2
# Clara                1.458741  0.045533  3.809828  0.663225
# Gema + Clara         0.969546  0.020186  1.984566  0.921678
# Massa Total Aferido  0.933375  0.016982  1.995700  0.930680

# %%
pd.DataFrame(Y_test, columns=objective_columns).to_csv('Y_test_color.csv')
pd.DataFrame(Y_pred, columns=objective_columns).to_csv('Y_pred_color.csv')

# %%
# Printar as métricas para cada objetivo

for col_name, metric_values in metrics.items():
    # print(f"Métricas para {col_name}: mae = {metric_values['MAE']:.2f}, mape = {100 * metric_values['MAPE']:.2f}%, mse = {metric_values['MSE']:.2f}, r2 = {metric_values['R2']:.2f}")
    send_telegram_message(f"Métricas para {col_name}: mae = {metric_values['MAE']:.2f}, mape = {100 * metric_values['MAPE']:.2f}%, mse = {metric_values['MSE']:.2f}, r2 = {metric_values['R2']:.2f}")
# Out:
# Mensagem enviada com sucesso!
# Mensagem enviada com sucesso!
# Mensagem enviada com sucesso!

# %%
import matplotlib.pyplot as plt
import os

# Criar uma pasta para salvar os gráficos, se não existir
output_dir = "graficos_preditos_vs_reais"
os.makedirs(output_dir, exist_ok=True)

# Criar gráficos para cada variável de saída
for col_name, df in result_dfs.items():
    plt.figure(figsize=(8, 6))
    
    # Gráfico de valor predito vs. valor real
    plt.scatter(df['real'], df['predict'], alpha=0.7, label='Predito vs Real')
    
    # Adicionar a linha ideal (diagonal) - a linha perfeita Y = X
    min_value = min(df['real'].min(), df['predict'].min())
    max_value = max(df['real'].max(), df['predict'].max())
    plt.plot([min_value, max_value], [min_value, max_value], 'r--', label='Ideal (Y=X)')

    # Adicionar título e rótulos
    plt.title(f"Comparação entre Valores Preditos e Reais para {col_name}")
    plt.xlabel("Valores Reais (Massa)")
    plt.ylabel("Valores Preditos (Massa)")
    plt.legend()
    plt.grid(True)

    # Salvar o gráfico em arquivo
    file_path = os.path.join(output_dir, f"grafico_predito_vs_real_{col_name}.png")
    plt.savefig(file_path)
    send_telegram_image(file_path)
    plt.close()

    print(f"Gráfico salvo em: {file_path}")

# Confirmar que os gráficos foram gerados
print("Todos os gráficos foram salvos com sucesso.")
# Out:
# Imagem enviada com sucesso!
# Gráfico salvo em: graficos_preditos_vs_reais/grafico_predito_vs_real_Massa Total Aferido.png
# Imagem enviada com sucesso!
# Gráfico salvo em: graficos_preditos_vs_reais/grafico_predito_vs_real_Clara.png
# Imagem enviada com sucesso!
# Gráfico salvo em: graficos_preditos_vs_reais/grafico_predito_vs_real_Gema + Clara.png
# Todos os gráficos foram salvos com sucesso.

# %%
# Exemplo de uso
from datetime import datetime
send_telegram_file(model_checkpoint_path, f"Modelo Treinado {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# Arquivo enviado com sucesso!

# %%
model_checkpoint_path
# Out:
# 'model_best_total_mass_mae_sam_color.keras'

# %%
msg = str(model.summary())
send_telegram_message(msg)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 64, 50, 50, 3)]   0
#
#  time_distributed (TimeDist  (None, 64, 48, 48, 16)    448
#  ributed)
#
#  time_distributed_1 (TimeDi  (None, 64, 24, 24, 16)    0
#  stributed)
#
#  time_distributed_2 (TimeDi  (None, 64, 22, 22, 8)     1160
#  stributed)
#
#  time_distributed_3 (TimeDi  (None, 64, 11, 11, 8)     0
#  stributed)
#
#  flatten (Flatten)           (None, 61952)             0
#
#  dense (Dense)               (None, 32)                1982496
#
#  batch_normalization (Batch  (None, 32)                128
#  Normalization)
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 3)                 51
#
# =================================================================
# Total params: 1984811 (7.57 MB)
# Trainable params: 1984747 (7.57 MB)
# Non-trainable params: 64 (256.00 Byte)
# _________________________________________________________________
# Mensagem enviada com sucesso!

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 64, 50, 50, 3)]   0
#
#  time_distributed (TimeDist  (None, 64, 48, 48, 16)    448
#  ributed)
#
#  time_distributed_1 (TimeDi  (None, 64, 24, 24, 16)    0
#  stributed)
#
#  time_distributed_2 (TimeDi  (None, 64, 22, 22, 8)     1160
#  stributed)
#
#  time_distributed_3 (TimeDi  (None, 64, 11, 11, 8)     0
#  stributed)
#
#  flatten (Flatten)           (None, 61952)             0
#
#  dense (Dense)               (None, 32)                1982496
#
#  batch_normalization (Batch  (None, 32)                128
#  Normalization)
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 3)                 51
#
# =================================================================
# Total params: 1984811 (7.57 MB)
# Trainable params: 1984747 (7.57 MB)
# Non-trainable params: 64 (256.00 Byte)
# _________________________________________________________________

# %%
send_telegram_message(f""" 
                      max_frames_by_color = {max_frames_by_color}
                      num_originals_per_egg = {num_originals_per_egg}
                      num_augmentations = {num_augmentations}
                      final_frame_shape = {final_frame_shape}
                      X_train.shape = {X_train.shape}
                      X_test.shape = {X_test.shape}
                      X_val.shape = {X_val.shape}
                      objective_columns = {objective_columns}
                      len train_indexes = {len(train_indexes)}
                      len test_indexes = {len(test_indexes)}
                      len validation_indexes = {len(validation_indexes)}
                      """)
# Out:
# Mensagem enviada com sucesso!

# %%
df.to_csv("predicoes_x_real.csv", index=False)
send_telegram_file("predicoes_x_real.csv", "Predições X Reais")
# Out:
# Arquivo enviado com sucesso!
